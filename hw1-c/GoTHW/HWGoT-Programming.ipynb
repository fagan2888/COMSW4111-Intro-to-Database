# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2020, Sections 002, H02, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Programming Project Notebook<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction
#
# - This notebook defines HW1, Part C for the programming track.
#
#
# - Submission instructions:
#     - Submit a zip file containing all of the files in the HW project directory that you clone (see below).
#     - Much of your work is completing sections of this notebook, but you MUST edit the copy in the project directory.
#     - If you reference or create any files, please create in the project directory.
#     - The name of your zip file MUST be ```uni_W4111_s20_hw1c,```  replace ```uni``` with you UNI. My submission would be ```dff9_W4111_s20_hw1c.```
#     - The homework is due on 23-February-2020 at 11:59 PM. You MAY use late days.
#
# - We will use the pinned [Piazza post](https://piazza.com/class/k5grpo7gmn71pj?cid=301) to clarify the homework and answer questions.
#
#
# # Common Setup
#
# Both tracks should:
# - MySQL: Install
#     - [MySQL Server Community Edition](https://dev.mysql.com/doc/mysql-installation-excerpt/8.0/en/)
#     - [MySQL Workbench](https://dev.mysql.com/doc/workbench/en/)
#     - In addition to the official links, there are many operating specific tutorials.
#
#
# - Create a [Lucidchart educational account.](https://lucidchart.zendesk.com/hc/en-us/articles/207324096-Get-Started-with-an-Educational-Account)
#
#
# - Project template:
#     - If you do not have ```Git``` on your computer, please install it.
#     - Homework 1 setup instructions recommended that you create a folder ```/IntroToDB``` on your desktop.
#     - Under this directory, create a folder ```HW1C.```
#     - Open terminal shell or Git enabled command prompt.
#     - CD to the directory you created and enter ```git clone https://github.com/donald-f-ferguson/GoTHW```
#     - This will create the project template for you.
#
# | <img src="./got_hw_project.png"> |
# | :---: |
# | __HW1C Project Template__ |

# %% [markdown]
# - Run the following cells. Your answers WILL BE different than the sample output.

# %%
import sys
import os
import platform
import psutil

print("="*40, "Path Information", "="*40)
print("Path = ", os.getcwd())

print("="*40, "System Information", "="*40)
uname = platform.uname()
print(f"System: {uname.system}")
print(f"Node Name: {uname.node}")
print(f"Release: {uname.release}")
print(f"Version: {uname.version}")
print(f"Machine: {uname.machine}")
print(f"Processor: {uname.processor}")

print("="*40, "Network Information", "="*40)

import socket    
hostname = socket.gethostname()    
IPAddr = socket.gethostbyname(hostname)    
print("Your Computer Name is:" + hostname)    
print("Your Computer IP Address is:" + IPAddr) 

import uuid
print ("Your MAC address is:", hex(uuid.getnode()))
# Out:
# ======================================== Path Information ========================================
# Path =  /Users/tsengyiping/Docker/jupyter/COMSW4111-Intro-to-Database/hw1-c/GoTHW
# ======================================== System Information ========================================
# System: Darwin
# Node Name: cengyipings-MacBook-Air.local
# Release: 18.6.0
# Version: Darwin Kernel Version 18.6.0: Thu Apr 25 23:16:27 PDT 2019; root:xnu-4903.261.4~2/RELEASE_X86_64
# Machine: x86_64
# Processor: i386
# ======================================== Network Information ========================================
# Your Computer Name is:cengyipings-MacBook-Air.local
# Your Computer IP Address is:192.168.0.132
# Your MAC address is: 0x6030d4631e40

# %% [markdown]
# # Programming
#
# ## Overview
#
# - Ensuring that programming track students build core skills is essential. Programming track assignments will contain a subset of the broader, more complete tasks assigned in the No programming assignments. So, there is a common core section to the programming track homework.
#
#
# - Additionally, the programming track will have tasks that reinforce skills necessary for programming and databases.
#
#
# ## Tasks
#
# - Data Import: Import the tables in the Data/csv folder
#
#
# - Data Cleanup: Clean up the imported tables
#
#
# - Schema Improvement: For the following tables, perform the schema improvement tasks
#     1. ```characters```
#     2. ```scenes```
#     3. ```scenes_characters```
#
#
# - Views: Create the following views
#     1. Implement the view "Character Interactions."
#     2. Define, explain and implement a view of you choosing.
#
#
# - Programming Section: Complete the implementation for the BaseDataTable and RDBDataTable classes

# %% [markdown]
# ## Task 1: Initial Data Import
#
# ### Task
#
# - The folder in the project ```Data/csv``` contains several CSV files:
#     - ```'character_relationships.csv```
#     - ```characters.csv```
#     - ```characters_actors.csv```
#     - ```episodes.csv```
#     - ```locations.csv```
#     - ```scenes.csv```
#     - ```scenes_characters.csv```
#
#
# - Use MySQL Workbench:
#     - Create a new schema ```W4111GoTSolution``` and set as the default schema.
#     - Use the MySQL [Workbench Table Data Import Wizard](https://dev.mysql.com/doc/workbench/en/wb-admin-export-import-table.html) and import each of the files. Choose the option to create a new table.

# %% [markdown]
# ### Tests

# %%
# %load_ext sql
# %sql mysql+pymysql://root:rv8855741@localhost/W4111GoTSolution
# Out:
# 'Connected: root@W4111GoTSolution'

# %% [markdown]
# ```1.``` Find all the characters with last name ```Stark.```

# %%
# %sql select * from characters where characterName like("% Stark")
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 14 rows affected.
# [(15, 'Arya Stark', '/character/ch0158604/', 'Maisie Williams', '/name/nm3586035/', 'CH_15', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1_SY1000_CR0,0,665,1000_AL_.jpg', '', ''),
#  (20, 'Benjen Stark', '/character/ch0153996/', 'Joseph Mawle', '/name/nm1152798/', 'CH_20', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjFiY2M5MjgtZmRiMS00ZTAyLTk2Y2UtMjdjZTRkZmVlYTMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjFiY2M5MjgtZmRiMS00ZTAyLTk2Y2UtMjdjZTRkZmVlYTMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (28, 'Brandon Stark', '', '', '', 'CH_28', '', '', '', '', ''),
#  (29, 'Bran Stark', '/character/ch0234897/', 'Isaac Hempstead Wright', '/name/nm3652842/', 'CH_29', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1NTg0NTI3MTBeQTJeQWpwZ15BbWU3MDEyNjg4OTQ@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1NTg0NTI3MTBeQTJeQWpwZ15BbWU3MDEyNjg4OTQ@._V1_SX1500_CR0,0,1500,999_AL_.jpg', '', ''),
#  (36, 'Catelyn Stark', '/character/ch0145135/', 'Michelle Fairley', '/name/nm0265610/', 'CH_36', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2ODc4MTkxMV5BMl5BanBnXkFtZTcwNjM3MTg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2ODc4MTkxMV5BMl5BanBnXkFtZTcwNjM3MTg4OQ@@._V1_SY1000_CR0,0,915,1000_AL_.jpg', '', ''),
#  (59, 'Eddard Stark', '/character/ch0154681/', 'Sean Bean', '/name/nm0000293/', 'CH_59', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1_SY1000_CR0,0,827,1000_AL_.jpg', 'Ned', ''),
#  (183, 'Lyanna Stark', '/character/ch0543804/', 'Aisling Franciosi', '/name/nm4957233/', 'CH_183', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTE5NTczY2QtNmQxYS00NTAwLWE2ZTAtYzc1MTkyZGU5MzRkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTE5NTczY2QtNmQxYS00NTAwLWE2ZTAtYzc1MTkyZGU5MzRkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (284, 'Rickard Stark', '', '', '', 'CH_284', '', '', '', '', ''),
#  (285, 'Rickon Stark', '/character/ch0233141/', 'Art Parkinson', '/name/nm3280686/', 'CH_285', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWZiOGNjMDAtOTRlNi00MDJmLWEyMTMtOGEwZTM5ODJlNDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWZiOGNjMDAtOTRlNi00MDJmLWEyMTMtOGEwZTM5ODJlNDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (286, 'Robb Stark', '/character/ch0158596/', 'Richard Madden', '/name/nm0534635/', 'CH_286', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2NDE1NzczNF5BMl5BanBnXkFtZTcwNjcwODg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2NDE1NzczNF5BMl5BanBnXkFtZTcwNjcwODg4OQ@@._V1_SY1000_CR0,0,845,1000_AL_.jpg', '', ''),
#  (300, 'Sansa Stark', '/character/ch0158137/', 'Sophie Turner', '/name/nm3849842/', 'CH_300', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg', '', ''),
#  (381, 'Young Benjen Stark', '/character/ch0153996/', 'Matteo Elezi', '/name/nm5502295/', 'CH_381', '', '', '', '', ''),
#  (383, 'Young Lyanna Stark', '/character/ch0543804/', 'Cordelia Hill', '/name/nm8108764/', 'CH_383', '', '', '', '', ''),
#  (386, 'Young Ned Stark', '/character/ch0154681/', 'Sebastian Croft', '/name/nm7509185/', 'CH_386', '', '', '', '', '')]

# %% [markdown]
# ```2.``` Find all of the information about scenes in season 1, episode 1.

# %%
# %sql select * from scenes where episodeNum=1 and seasonNum=1 limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 10 rows affected.
# [(0, 1, 1, 1, '0:00:40', '0:01:45', 'The Wall', 'Castle Black', '', '', '', ''),
#  (1, 1, 1, 2, '0:01:45', '0:03:24', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (2, 1, 1, 3, '0:03:24', '0:03:31', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (3, 1, 1, 4, '0:03:31', '0:03:38', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (4, 1, 1, 5, '0:03:38', '0:03:44', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (5, 1, 1, 6, '0:03:44', '0:05:36', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (6, 1, 1, 7, '0:05:36', '0:05:41', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (7, 1, 1, 8, '0:05:41', '0:05:48', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (8, 1, 1, 9, '0:05:48', '0:05:58', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (9, 1, 1, 10, '0:05:58', '0:06:21', 'North of the Wall', 'The Haunted Forest', '', '', '', '')]

# %% [markdown]
# ```3.``` Find all of the characters and actors who played them.

# %%
# %%sql
# SELECT
#     character_id,
#     (select characterName from characters where characters.character_id=
#          characters_actors.character_id) as characterName,
#     actorName, season
# FROM W4111GoTSolution.characters_actors
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolution
# 10 rows affected.
# [('CH_0', 'Addam Marbrand', 'B.J. Hogg', ''),
#  ('CH_2', 'Aeron Greyjoy', 'Michael Feast', ''),
#  ('CH_3', 'Aerys II Targaryen', 'David Rintoul', ''),
#  ('CH_4', 'Akho', 'Chuku Modu', ''),
#  ('CH_5', 'Alliser Thorne', 'Owen Teale', ''),
#  ('CH_6', 'Alton Lannister', 'Karl Davies', ''),
#  ('CH_7', 'Alys Karstark', 'Megan Parkinson', ''),
#  ('CH_8', 'Amory Lorch', 'Fintan McKeown', ''),
#  ('CH_9', 'Anguy', 'Philip McGinley', ''),
#  ('CH_10', 'Archmaester Marwyn', 'Jim Broadbent', '')]

# %% [markdown]
# ## Data Cleanup
#
# ### Task 2
#
# - CSV files are _text_ files, and all data is character strings.
#
#
# - Spreadsheet applications, like Excel, and the data import tools in databases can _infer_ column types in some cases. For example, consider the table definition created for importing ```scenes_characters.```
#
# ```
# CREATE TABLE `scenes_characters` (
#   `id` int(11) DEFAULT NULL,
#   `seasonNum` int(11) DEFAULT NULL,
#   `episodeNum` int(11) DEFAULT NULL,
#   `sceneNo` int(11) DEFAULT NULL,
#   `characterName` text
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_0900_ai_ci;
#
# ```
#
#
# - The import process inferred that some columns in the CSV file are text representations of integers, and performed conversion.
#
#
# - The process is unreliable, and does not always work.
#
#
# - For this task, you must modify column definitions and data valaues to represent the correct the meaning of the data. We will cover keys in the next task.
#
#
# - Execute your DDL and DML SQL in cells below. You can add Markdown cells to explain what you are doing.
#
#
# - My approach is to create a new schema with corrected table definitions and cleaned copies of the data. This preserves the original data for data lineage and avoids possible information loss.
#
#
# - Call your new schema ```W4111GoTSolutionClean.```
#
#
# - An example using a table called groups is given below
#
#
# - __NOTE:__ You can use MySQL Workbench or other tools to help you write the DDL and DML statements, but you MUST execute the statements in the cells below.

# %% [markdown]
# - Create the Schema:

# %%
# %load_ext sql
# %sql mysql+pymysql://root:rv8855741@localhost/W4111GoTSolutionClean
# Out:
# 'Connected: root@W4111GoTSolutionClean'

# %% [markdown]
# #### Example: Groups
#
# - You should have similar queries for the tables that you are cleaning up.
#
# - Create a table with clean data
#
# %%sql
# create table W4111GotSolutionClean.groups (id int, groupName varchar(32), characterName varchar(32))
#
# - Insert the data into the new table from the original
#
# %%sql insert into W4111GotSolutionClean.groups
# select id, groupName, `character` from W4111GotSolution.groups;
#
# - Check to make sure the data imported successfully
#
# %sql select count(*) from W4111GotSolution.groups
#
#  - ```''``` is a common way to represent "unknown" or "not applicable" in text data.[Codd's Rule no. 3](https://www.webopedia.com/TERM/C/Codds_Rules.html) defines the systmatic treatment of unknown or  not applicable data. So we should update this accordingly.
#
# %%sql update W4111GoTSolutionClean.groups set characterName=NULL where characterName=''

# %% [markdown]
# ## Answers

# %% [markdown]
# __characters__

# %%
# %%sql
# SELECT MAX(LENGTH(characterName)) AS characterName_length,
#     MAX(LENGTH(characterLink)) AS characterLink_length,
#     MAX(LENGTH(actorName)) AS actorName_length,
#     MAX(LENGTH(actorLink)) AS actorLink_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(characterimageThumb)) AS characterimageThumb_length,
#     MAX(LENGTH(characterimageFull)) AS characterimageFull_length,
#     MAX(LENGTH(nickname)) AS nickname_length
#     FROM W4111GoTSolution.characters
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(28, 37, 29, 16, 6, 167, 250, 14)]

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.characters
#     AS SELECT * FROM W4111GoTSolution.characters
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters`
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `characterLink` `characterLink` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageThumb` `characterImageThumb` VARCHAR(256) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageFull` `characterImageFull` VARCHAR(256) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
# CHANGE COLUMN `nickname` `nickname` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
# ADD PRIMARY KEY (`id`),
# ADD UNIQUE INDEX `character_id_UNIQUE` (`character_id` ASC) VISIBLE;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe W4111GoTSolutionClean.characters
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(64)', 'YES', '', None, ''),
#  ('actorName', 'varchar(32)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'text', 'YES', '', None, ''),
#  ('characterImageThumb', 'varchar(256)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(256)', 'YES', '', None, ''),
#  ('nickname', 'varchar(32)', 'YES', '', None, ''),
#  ('kingsguard', 'text', 'YES', '', None, '')]

# %%
# %sql SELECT * FROM W4111GoTSolutionClean.characters where characterName is NULL;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM W4111GoTSolutionClean.characters where actorName is NULL;
# %sql SELECT * FROM W4111GoTSolutionClean.characters where actorName="" LIMIT 5;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [(1, 'Aegon Targaryen', '', '', '', 'CH_1', 'True', '', '', '', ''),
#  (16, 'Baby Sam', '/character/ch0547881/', '', '', 'CH_16', '', '', '', '', ''),
#  (21, 'Beric Dondarrion', '/character/ch0305320/', '', '', 'CH_21', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTEwNTg2MF5BMl5BanBnXkFtZTgwNTAxODYxOTE@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTEwNTg2MF5BMl5BanBnXkFtZTgwNTAxODYxOTE@._V1_SY1000_CR0,0,665,1000_AL_.jpg', '', ''),
#  (28, 'Brandon Stark', '', '', '', 'CH_28', '', '', '', '', ''),
#  (43, 'Daario Naharis', '/character/ch0335040/', '', '', 'CH_43', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BY2ExMDJmNzMtMDVmZi00MDNlLWI1NzYtOTkxOTdlOWU4YzE4XkEyXkFqcGdeQXVyNTcxMzMwNTA@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BY2ExMDJmNzMtMDVmZi00MDNlLWI1NzYtOTkxOTdlOWU4YzE4XkEyXkFqcGdeQXVyNTcxMzMwNTA@._V1_SY1000_CR0,0,665,1000_AL_.jpg', '', '')]

# %%
# %%sql
#     UPDATE characters SET actorName=NULL where actorName="";
#     UPDATE characters SET characterLink=NULL WHERE characterLink="";
#     UPDATE characters SET actorName=NULL WHERE actorName="";
#     UPDATE characters SET actorLink=NULL WHERE actorLink="";
#     UPDATE characters SET characterImageThumb=NULL WHERE characterImageThumb="";
#     UPDATE characters SET characterImageFull=NULL WHERE characterImageFull="";
#     UPDATE characters SET nickname=NULL WHERE nickname="";
#     UPDATE characters SET royal=1 WHERE royal="True";
#     UPDATE characters SET royal=0 WHERE royal="";
#     UPDATE characters SET kingsguard=1 WHERE kingsguard="True";
#     UPDATE characters SET kingsguard=0 WHERE kingsguard="";
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 35 rows affected.
# 21 rows affected.
# 0 rows affected.
# 36 rows affected.
# 134 rows affected.
# 134 rows affected.
# 380 rows affected.
# 17 rows affected.
# 372 rows affected.
# 5 rows affected.
# 384 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters`
#     CHANGE COLUMN `royal` `royal` TINYINT NOT NULL DEFAULT 0 ,
#     CHANGE COLUMN `kingsguard` `kingsguard` TINYINT NOT NULL DEFAULT 0 ;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %sql describe W4111GoTSolutionClean.characters
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(64)', 'YES', '', None, ''),
#  ('actorName', 'varchar(32)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'tinyint', 'NO', '', '0', ''),
#  ('characterImageThumb', 'varchar(256)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(256)', 'YES', '', None, ''),
#  ('nickname', 'varchar(32)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint', 'NO', '', '0', '')]

# %%
# %sql SELECT id, royal FROM characters WHERE royal=1 LIMIT 5;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [(1, 1), (3, 1), (29, 1), (38, 1), (44, 1)]

# %% [markdown]
# __character_relationships__
#
# - There is some serialized JSON in the ```value``` column for ```actor.```
#
#
# - Also, ```actor``` is redundant and we will need to remove later. It is here because we have to do some additional processing code to better align character relationships with scene information. We know ```character-actor``` mapping but until we factor in scenes, we are not sure which actor if there was more than one.

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.character_relationships
#     AS SELECT * FROM W4111GoTSolution.character_relationships
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 890 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(characterName)) AS characterName_length,
#     MAX(LENGTH(label)) AS label_length,
#     MAX(LENGTH(value)) AS value_length
#     FROM character_relationships
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 6, 24, 14, 112)]

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`character_relationships`
#     CHANGE COLUMN `id` `id` INT NOT NULL ,
#     CHANGE COLUMN `character_id` `character_id` VARCHAR(8) NOT NULL ,
#     CHANGE COLUMN `characterName` `characterName` VARCHAR(32) NOT NULL ,
#     CHANGE COLUMN `label` `label` VARCHAR(16) NULL DEFAULT NULL ,
#     CHANGE COLUMN `value` `value` VARCHAR(128) NULL DEFAULT NULL ,
#     ADD PRIMARY KEY (`id`, `character_id`);
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 890 rows affected.
# []

# %%
# %sql DESCRIBE character_relationships;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(8)', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('label', 'varchar(16)', 'YES', '', None, ''),
#  ('value', 'varchar(128)', 'YES', '', None, '')]

# %% [markdown]
# __characters_actors__

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.characters_actors
#     AS SELECT * FROM W4111GoTSolution.characters_actors
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 408 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(actorName)) AS actorName_length,
#     MAX(LENGTH(actorLink)) AS actorLink_length,
#     MAX(LENGTH(season)) AS season_length
#     FROM characters_actors
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 6, 29, 16, 3)]

# %%
# %%sql
#     UPDATE characters_actors SET season=1 WHERE season='1.0';
#     UPDATE characters_actors SET season=2 WHERE season='2.0';
#     UPDATE characters_actors SET season=3 WHERE season='3.0';
#     UPDATE characters_actors SET season=4 WHERE season='4.0';
#     UPDATE characters_actors SET season=5 WHERE season='5.0';
#     UPDATE characters_actors SET season=6 WHERE season='6.0';
#     UPDATE characters_actors SET season=7 WHERE season='7.0';
#     UPDATE characters_actors SET season=8 WHERE season='8.0';
#     UPDATE characters_actors SET season=NULL WHERE season='';
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 354 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters_actors`
#     CHANGE COLUMN `id` `id` INT NOT NULL ,
#     CHANGE COLUMN `character_id` `character_id` VARCHAR(8) NOT NULL ,
#     CHANGE COLUMN `actorName` `actorName` VARCHAR(32) NOT NULL ,
#     CHANGE COLUMN `actorLink` `actorLink` VARCHAR(32) NULL DEFAULT NULL ,
#     CHANGE COLUMN `season` `season` INT NULL DEFAULT NULL ,
#     ADD PRIMARY KEY (`id`, `character_id`);
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 408 rows affected.
# []

# %%
# %sql DESCRIBE characters_actors;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(8)', 'NO', 'PRI', None, ''),
#  ('actorName', 'varchar(32)', 'NO', '', None, ''),
#  ('actorLink', 'varchar(32)', 'YES', '', None, ''),
#  ('season', 'int', 'YES', '', None, '')]

# %% [markdown]
# __scenes__

# %%
# %%sql
# SELECT MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(sceneNo)) AS sceneNo_length,
#     MAX(LENGTH(sceneStart)) AS sceneStart_length,
#     MAX(LENGTH(sceneEnd)) AS sceneEnd_length,
#     MAX(LENGTH(location)) AS location_length,
#     MAX(LENGTH(subLocation)) AS subLocation_length,
#     MAX(LENGTH(greensight)) AS greensight_length,
#     MAX(LENGTH(altLocation)) AS altLocation_length,
#     MAX(LENGTH(warg)) AS warg_length,
#     MAX(LENGTH(flashback)) AS flashback_length
#     FROM W4111GoTSolution.scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(1, 2, 3, 7, 7, 17, 37, 4, 24, 4, 4)]

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.scenes
#     AS SELECT * FROM W4111GoTSolution.scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# []

# %%
# %%sql
#     UPDATE scenes SET greensight=1 WHERE greensight="True";
#     UPDATE scenes SET greensight=0 WHERE greensight="";
#     UPDATE scenes SET warg=1 WHERE warg="True";
#     UPDATE scenes SET warg=0 WHERE warg="";
#     UPDATE scenes SET flashback=1 WHERE flashback="True";
#     UPDATE scenes SET flashback=0 WHERE flashback="";
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 16 rows affected.
# 4149 rows affected.
# 7 rows affected.
# 4158 rows affected.
# 41 rows affected.
# 4124 rows affected.
# []

# %%
# %%sql
#     ALTER TABLE `W4111GoTSolutionClean`.`scenes`
#     CHANGE COLUMN `id` `id` INT NOT NULL ,
#     CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
#     CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
#     CHANGE COLUMN `sceneNo` `sceneNo` INT NOT NULL ,
#     CHANGE COLUMN `sceneStart` `sceneStart` TIME NOT NULL ,
#     CHANGE COLUMN `sceneEnd` `sceneEnd` TIME NOT NULL ,
#     CHANGE COLUMN `location` `location` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
#     CHANGE COLUMN `subLocation` `subLocation` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
#     CHANGE COLUMN `greensight` `greensight` TINYINT NOT NULL ,
#     CHANGE COLUMN `altLocation` `altLocation` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
#     CHANGE COLUMN `warg` `warg` TINYINT NOT NULL ,
#     CHANGE COLUMN `flashback` `flashback` TINYINT NOT NULL ,
#     ADD PRIMARY KEY (`seasonNum`, `episodeNum`, `sceneNo`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# []

# %%
# %sql describe W4111GoTSolutionClean.scenes
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 12 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('sceneStart', 'time', 'NO', '', None, ''),
#  ('sceneEnd', 'time', 'NO', '', None, ''),
#  ('location', 'varchar(32)', 'YES', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, ''),
#  ('greensight', 'tinyint', 'NO', '', None, ''),
#  ('altLocation', 'varchar(32)', 'YES', '', None, ''),
#  ('warg', 'tinyint', 'NO', '', None, ''),
#  ('flashback', 'tinyint', 'NO', '', None, '')]

# %% [markdown]
# __scenes_characters__

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.scenes_characters
#     AS SELECT * FROM W4111GoTSolution.scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql SELECT DISTINCT id, characterName FROM W4111GoTSolutionClean.scenes_characters
#     WHERE characterName NOT IN (
#         SELECT characterName FROM characters
#     )
#     ORDER BY id ASC;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(sceneNo)) AS sceneNo_length,
#     MAX(LENGTH(characterName)) AS characterName_length
#     FROM scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(5, 1, 2, 3, 34)]

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
#     CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
#     CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
#     CHANGE COLUMN `sceneNo` `sceneNo` INT NOT NULL ,
#     CHANGE COLUMN `characterName` `characterName` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
#     ADD PRIMARY KEY (`seasonNum`, `episodeNum`, `sceneNo`, `characterName`);
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe scenes_characters
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', 'PRI', None, '')]

# %% [markdown]
# __episodes__

# %%
# %%sql
#     SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(episodeTitle)) AS episodeTitle_length,
#     MAX(LENGTH(episodeLink)) AS episodeLink_length,
#     MAX(LENGTH(episodeAirDate)) AS episodeAirDate_length,
#     MAX(LENGTH(episodeDescription)) AS episodeDescription_length
#     FROM W4111GoTSolution.episdes;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(2, 1, 2, 37, 17, 10, 238)]

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.episdes
#     AS SELECT * FROM W4111GoTSolution.episdes
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 73 rows affected.
# []

# %%
# %%sql
#     ALTER TABLE `W4111GoTSolutionClean`.`episdes`
#     CHANGE COLUMN `id` `id` INT NOT NULL ,
#     CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
#     CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
#     CHANGE COLUMN `episodeTitle` `episodeTitle` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
#     CHANGE COLUMN `episodeLink` `episodeLink` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
#     CHANGE COLUMN `episodeAirDate` `episodeAirDate` DATETIME NOT NULL ,
#     CHANGE COLUMN `episodeDescription` `episodeDescription` VARCHAR(256) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
#     ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 73 rows affected.
# []

# %%
# %sql describe W4111GoTSolutionClean.episdes
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 7 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', '', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('episodeTitle', 'varchar(64)', 'NO', '', None, ''),
#  ('episodeLink', 'varchar(64)', 'NO', '', None, ''),
#  ('episodeAirDate', 'datetime', 'NO', '', None, ''),
#  ('episodeDescription', 'varchar(256)', 'NO', '', None, '')]

# %% [markdown]
# __locations__

# %%
# %%sql
#     SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(location)) AS location_length,
#     MAX(LENGTH(subLocation)) AS subLocation_length
#     FROM W4111GoTSolution.locations
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 17, 37)]

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.locations
#     AS SELECT * FROM W4111GoTSolution.locations
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 129 rows affected.
# []

# %%
# %%sql
#     ALTER TABLE `W4111GoTSolutionClean`.`locations`
#     CHANGE COLUMN `id` `id` INT NOT NULL ,
#     CHANGE COLUMN `location` `location` VARCHAR(32) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ,
#     CHANGE COLUMN `subLocation` `subLocation` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NULL DEFAULT NULL ,
#     ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 129 rows affected.
# []

# %%
# %sql DESCRIBE `W4111GoTSolutionClean`.`locations`;
# Out:
#    mysql+pymysql://root:***@localhost/W4111GoTSolution
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 3 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(32)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# ## Task 3
#
# ### Keys and Data Integrity
#
# - Correct analysis and management of the data requires defining keys and integrity constraints.
#
#
# - Use DML statements to modify the schema to create the constraints you think best.
#
#
# - The following diagram is my definition, but this is an example and may not be correct. It is simply to help you get started.
#
# | <img src="./got_er_model.png"> |
# | :---: |
# |__GoT ER Model__ |

# %%
# %sql DROP TABLE IF EXISTS character_ids;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql CREATE TABLE `W4111GoTSolutionClean`.`character_ids` (
#   `auto_id` INT NOT NULL AUTO_INCREMENT,
#   `characterName` VARCHAR(128) NULL,
#   `real_id` INT NULL,
#   `character_id` VARCHAR(16) GENERATED ALWAYS AS (concat("CH_", real_id)) STORED,
#   PRIMARY KEY (`auto_id`));
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql INSERT INTO character_ids(characterName, real_id)
#     SELECT characterName, id FROM characters
#     ORDER BY id ASC;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 627 rows affected.
# []

# %%
# %%sql INSERT INTO character_ids(characterName)
#     SELECT DISTINCT characterName FROM scenes_characters
#     WHERE characterName NOT IN (
#         SELECT characterName FROM characters
#     );
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql UPDATE character_ids
#     SET real_id = auto_id-1
#     WHERE real_id IS NULL;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters`
#     CHANGE COLUMN `characterName` `characterName` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql INSERT INTO characters(id, characterName, character_id)
#     SELECT real_id, characterName, character_id FROM character_ids
#     WHERE characterName NOT IN (
#         SELECT characterName FROM characters
#     );
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %% [markdown]
# - Scenes and Characters

# %%
# %%sql ALTER TABLE scenes_characters
#     ADD character_id VARCHAR(16) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql SELECT SC.characterName, C.character_id FROM scenes_characters AS SC
#     JOIN characters AS C
#     ON SC.characterName=C.characterName;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 12270 rows affected.
# [('Gared', 'CH_68'),
#  ('Waymar Royce', 'CH_360'),
#  ('Will', 'CH_368'),
#  ('Gared', 'CH_68'),
#  ('Waymar Royce', 'CH_360'),
#  ('Will', 'CH_368'),
#  ('Wight Wildling Girl', 'CH_366'),
#  ('Will', 'CH_368'),
#  ('Will', 'CH_368'),
#  ('Gared', 'CH_68'),
#  ('Waymar Royce', 'CH_360'),
#  ('Will', 'CH_368'),
#  ('Will', 'CH_368'),
#  ('Gared', 'CH_68'),
#  ('Waymar Royce', 'CH_360'),
#  ('Will', 'CH_368'),
#  ('Gared', 'CH_68'),
#  ('Waymar Royce', 'CH_360'),
#  ('White Walker', 'CH_362'),
#  ('White Walker', 'CH_363'),
#  ('White Walker', 'CH_364'),
#  ('Will', 'CH_368'),
#  ('Wight Wildling Girl', 'CH_366'),
#  ('Will', 'CH_368'),
#  ('Gared', 'CH_68'),
#  ('White Walker', 'CH_362'),
#  ('White Walker', 'CH_363'),
#  ('White Walker', 'CH_364'),
#  ('Will', 'CH_368'),
#  ('Arya Stark', 'CH_15'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jon Snow', 'CH_123'),
#  ('Rickon Stark', 'CH_285'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Will', 'CH_368'),
#  ('Bran Stark', 'CH_29'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jon Snow', 'CH_123'),
#  ('Jory Cassel', 'CH_126'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Will', 'CH_368'),
#  ('Bran Stark', 'CH_29'),
#  ('Eddard Stark', 'CH_59'),
#  ('Ghost', 'CH_72'),
#  ('Grey Wind', 'CH_90'),
#  ('Jon Snow', 'CH_123'),
#  ('Jory Cassel', 'CH_126'),
#  ('Lady', 'CH_150'),
#  ('Nymeria', 'CH_242'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Shaggydog', 'CH_311'),
#  ('Summer', 'CH_326'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Jon Arryn', 'CH_122'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Maester Luwin', 'CH_188'),
#  ('Jon Snow', 'CH_123'),
#  ('Robb Stark', 'CH_286'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Arya Stark', 'CH_15'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Hodor', 'CH_102'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Jon Snow', 'CH_123'),
#  ('Jory Cassel', 'CH_126'),
#  ('Maester Luwin', 'CH_188'),
#  ('Myrcella Baratheon', 'CH_229'),
#  ('Rickon Stark', 'CH_285'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Summer', 'CH_326'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Tommen Baratheon', 'CH_344'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Ros', 'CH_293'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Illyrio Mopatis', 'CH_107'),
#  ('Khal Drogo', 'CH_133'),
#  ('Qotho', 'CH_265'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Illyrio Mopatis', 'CH_107'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Sansa Stark', 'CH_300'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Benjen Stark', 'CH_20'),
#  ('Jon Snow', 'CH_123'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Arya Stark', 'CH_15'),
#  ('Benjen Stark', 'CH_20'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Robb Stark', 'CH_286'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Sansa Stark', 'CH_300'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Maester Luwin', 'CH_188'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Drogon', 'CH_57'),
#  ('Illyrio Mopatis', 'CH_107'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Qotho', 'CH_265'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Khal Drogo', 'CH_133'),
#  ('Benjen Stark', 'CH_20'),
#  ('Bran Stark', 'CH_29'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robb Stark', 'CH_286'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Summer', 'CH_326'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bran Stark', 'CH_29'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Summer', 'CH_326'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jhiqui', 'CH_119'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Myrcella Baratheon', 'CH_229'),
#  ('Tommen Baratheon', 'CH_344'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Jon Snow', 'CH_123'),
#  ('Arya Stark', 'CH_15'),
#  ('Jon Snow', 'CH_123'),
#  ('Nymeria', 'CH_242'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jon Snow', 'CH_123'),
#  ('Jon Snow', 'CH_123'),
#  ('Robb Stark', 'CH_286'),
#  ('Benjen Stark', 'CH_20'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jon Snow', 'CH_123'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Drogon', 'CH_57'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Benjen Stark', 'CH_20'),
#  ('Ghost', 'CH_72'),
#  ('Jon Snow', 'CH_123'),
#  ('Rast', 'CH_271'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Catspaw Assassin', 'CH_37'),
#  ('Maester Luwin', 'CH_188'),
#  ('Robb Stark', 'CH_286'),
#  ('Summer', 'CH_326'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Drogon', 'CH_57'),
#  ('Irri', 'CH_109'),
#  ('Jhiqui', 'CH_119'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Benjen Stark', 'CH_20'),
#  ('Jon Snow', 'CH_123'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Maester Luwin', 'CH_188'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Bran Stark', 'CH_29'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Drogon', 'CH_57'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Ilyn Payne', 'CH_108'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Lady', 'CH_150'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Arya Stark', 'CH_15'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Mycah', 'CH_227'),
#  ('Nymeria', 'CH_242'),
#  ('Sansa Stark', 'CH_300'),
#  ('Arya Stark', 'CH_15'),
#  ('Nymeria', 'CH_242'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Arya Stark', 'CH_15'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Ilyn Payne', 'CH_108'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Jory Cassel', 'CH_126'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Sansa Stark', 'CH_300'),
#  ('Eddard Stark', 'CH_59'),
#  ('Mycah', 'CH_227'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Bran Stark', 'CH_29'),
#  ('Summer', 'CH_326'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lady', 'CH_150'),
#  ('Bran Stark', 'CH_29'),
#  ('Summer', 'CH_326'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lady', 'CH_150'),
#  ('Bran Stark', 'CH_29'),
#  ('Summer', 'CH_326'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Royal Steward', 'CH_295'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Bran Stark', 'CH_29'),
#  ('Old Nan', 'CH_246'),
#  ('Robb Stark', 'CH_286'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Grenn', 'CH_89'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Lancel Lannister', 'CH_152'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rakharo', 'CH_268'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Benjen Stark', 'CH_20'),
#  ('Jon Snow', 'CH_123'),
#  ('Benjen Stark', 'CH_20'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Yoren', 'CH_380'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Irri', 'CH_109'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Rakharo', 'CH_268'),
#  ('Grenn', 'CH_89'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Maester Aemon', 'CH_186'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Drogon', 'CH_57'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Jon Snow', 'CH_123'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Syrio Forel', 'CH_327'),
#  ('Bran Stark', 'CH_29'),
#  ('Three-Eyed Raven', 'CH_339'),
#  ('Bran Stark', 'CH_29'),
#  ('Hodor', 'CH_102'),
#  ('Old Nan', 'CH_246'),
#  ('Summer', 'CH_326'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Bran Stark', 'CH_29'),
#  ('Grey Wind', 'CH_90'),
#  ('Hodor', 'CH_102'),
#  ('Maester Luwin', 'CH_188'),
#  ('Robb Stark', 'CH_286'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Yoren', 'CH_380'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Doreah', 'CH_53'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Janos Slynt', 'CH_114'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jon Snow', 'CH_123'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Eddard Stark', 'CH_59'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Hugh of the Vale', 'CH_106'),
#  ('Jory Cassel', 'CH_126'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Eddard Stark', 'CH_59'),
#  ('Gendry', 'CH_70'),
#  ('Tobho Mott', 'CH_341'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Jory Cassel', 'CH_126'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Ghost', 'CH_72'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Jon Snow', 'CH_123'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Arya Stark', 'CH_15'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Gregor Clegane', 'CH_87'),
#  ('Hugh of the Vale', 'CH_106'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Myrcella Baratheon', 'CH_229'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Tommen Baratheon', 'CH_344'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Bronn', 'CH_32'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Marillion', 'CH_201'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Yoren', 'CH_380'),
#  ('Eddard Stark', 'CH_59'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Eddard Stark', 'CH_59'),
#  ('Hugh of the Vale', 'CH_106'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Eddard Stark', 'CH_59'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lancel Lannister', 'CH_152'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Gregor Clegane', 'CH_87'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Loras Tyrell', 'CH_174'),
#  ('Myrcella Baratheon', 'CH_229'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Tommen Baratheon', 'CH_344'),
#  ('Bronn', 'CH_32'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Marillion', 'CH_201'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bran Stark', 'CH_29'),
#  ('Maester Luwin', 'CH_188'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Ros', 'CH_293'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Lord Varys', 'CH_177'),
#  ('Arya Stark', 'CH_15'),
#  ('Illyrio Mopatis', 'CH_107'),
#  ('Lord Varys', 'CH_177'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Arya Stark', 'CH_15'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Yoren', 'CH_380'),
#  ('Arya Stark', 'CH_15'),
#  ('Jory Cassel', 'CH_126'),
#  ('Eddard Stark', 'CH_59'),
#  ('Yoren', 'CH_380'),
#  ('Bronn', 'CH_32'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Vardis Egen', 'CH_352'),
#  ('Eddard Stark', 'CH_59'),
#  ('Royal Steward', 'CH_295'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Eddard Stark', 'CH_59'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Lysa Arryn', 'CH_184'),
#  ('Robin Arryn', 'CH_289'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Vardis Egen', 'CH_352'),
#  ('Mord', 'CH_217'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Loras Tyrell', 'CH_174'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Eddard Stark', 'CH_59'),
#  ('Mhaegen', 'CH_212'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jory Cassel', 'CH_126'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Eddard Stark', 'CH_59'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Jory Cassel', 'CH_126'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Drogon', 'CH_57'),
#  ('Irri', 'CH_109'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Bran Stark', 'CH_29'),
#  ('Three-Eyed Raven', 'CH_339'),
#  ('Bran Stark', 'CH_29'),
#  ('Hodor', 'CH_102'),
#  ('Bran Stark', 'CH_29'),
#  ('Robb Stark', 'CH_286'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Bran Stark', 'CH_29'),
#  ('Osha', 'CH_253'),
#  ('Robb Stark', 'CH_286'),
#  ('Stiv', 'CH_324'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Wallen', 'CH_358'),
#  ('Mord', 'CH_217'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Arya Stark', 'CH_15'),
#  ('Syrio Forel', 'CH_327'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Dothraki Crone', 'CH_511'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rhaego', 'CH_280'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Drogon', 'CH_57'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Rhaegal', 'CH_278'),
#  ('Viserion', 'CH_354'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Mord', 'CH_217'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Lysa Arryn', 'CH_184'),
#  ('Robin Arryn', 'CH_289'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Vardis Egen', 'CH_352'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Lancel Lannister', 'CH_152'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Beric Dondarrion', 'CH_21'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Joss', 'CH_512'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Bronn', 'CH_32'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Lysa Arryn', 'CH_184'),
#  ('Mord', 'CH_217'),
#  ('Robin Arryn', 'CH_289'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Vardis Egen', 'CH_352'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Ros', 'CH_293'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Sansa Stark', 'CH_300'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Qotho', 'CH_265'),
#  ('Viserys Targaryen', 'CH_355'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Tywin Lannister', 'CH_350'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Armeca', 'CH_12'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Ros', 'CH_293'),
#  ('Maester Luwin', 'CH_188'),
#  ('Osha', 'CH_253'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Jon Snow', 'CH_123'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Eddard Stark', 'CH_59'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Lord Varys', 'CH_177'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Khal Drogo', 'CH_133'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Rakharo', 'CH_268'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Little Bird', 'CH_163'),
#  ('Little Bird', 'CH_164'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Rakharo', 'CH_268'),
#  ('Wine Merchant', 'CH_371'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Grenn', 'CH_89'),
#  ('Jaremy Rykker', 'CH_117'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Maester Aemon', 'CH_186'),
#  ('Othell Yarwyck', 'CH_254'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Eddard Stark', 'CH_59'),
#  ('Renly Baratheon', 'CH_277'),
#  ('Eddard Stark', 'CH_59'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Tomard', 'CH_343'),
#  ('Ghost', 'CH_72'),
#  ('Jon Snow', 'CH_123'),
#  ('Othell Yarwyck', 'CH_254'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Ghost', 'CH_72'),
#  ('Jon Snow', 'CH_123'),
#  ('Othell Yarwyck', 'CH_254'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Rakharo', 'CH_268'),
#  ('Wine Merchant', 'CH_371'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Qotho', 'CH_265'),
#  ('Wine Merchant', 'CH_371'),
#  ('Eddard Stark', 'CH_59'),
#  ('Robert Baratheon', 'CH_287'),
#  ('Royal Steward', 'CH_295'),
#  ('Varly', 'CH_353'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Eddard Stark', 'CH_59'),
#  ('Janos Slynt', 'CH_114'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Royal Steward', 'CH_295'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Janos Slynt', 'CH_114'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Royal Steward', 'CH_295'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Arya Stark', 'CH_15'),
#  ('Syrio Forel', 'CH_327'),
#  ('Arya Stark', 'CH_15'),
#  ('Syrio Forel', 'CH_327'),
#  ('Vayon Poole', 'CH_513'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Arya Stark', 'CH_15'),
#  ('Meryn Trant', 'CH_211'),
#  ('Syrio Forel', 'CH_327'),
#  ('Arya Stark', 'CH_15'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Arya Stark', 'CH_15'),
#  ('Red Keep Stableboy', 'CH_274'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lord Varys', 'CH_177'),
#  ('Jafer Flowers', 'CH_112'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Othell Yarwyck', 'CH_254'),
#  ('Othor', 'CH_255'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Sansa Stark', 'CH_300'),
#  ('Maester Luwin', 'CH_188'),
#  ('Robb Stark', 'CH_286'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Lysa Arryn', 'CH_184'),
#  ('Robin Arryn', 'CH_289'),
#  ('Bronn', 'CH_32'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Shagga', 'CH_310'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Alliser Thorne', 'CH_5'),
#  ('Grenn', 'CH_89'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Ghost', 'CH_72'),
#  ('Jon Snow', 'CH_123'),
#  ('Ghost', 'CH_72'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Othor', 'CH_255'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Mago', 'CH_192'),
#  ('Mirri Maz Duur', 'CH_215'),
#  ('Rakharo', 'CH_268'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Mago', 'CH_192'),
#  ('Mirri Maz Duur', 'CH_215'),
#  ('Qotho', 'CH_265'),
#  ('Rakharo', 'CH_268'),
#  ('Bran Stark', 'CH_29'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Grey Wind', 'CH_90'),
#  ('Robb Stark', 'CH_286'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Bran Stark', 'CH_29'),
#  ('Rickon Stark', 'CH_285'),
#  ('Robb Stark', 'CH_286'),
#  ('Bran Stark', 'CH_29'),
#  ('Hodor', 'CH_102'),
#  ('Osha', 'CH_253'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Robb Stark', 'CH_286'),
#  ('Bronn', 'CH_32'),
#  ('Shagga', 'CH_310'),
#  ('Timett', 'CH_340'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Chella', 'CH_514'),
#  ('Kevan Lannister', 'CH_132'),
#  ('Lannister Messenger', 'CH_156'),
#  ('Shagga', 'CH_310'),
#  ('Timett', 'CH_340'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Tywin Lannister', 'CH_350'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Lannister Scout', 'CH_157'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Lannister Scout', 'CH_157'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Eddard Stark', 'CH_59'),
#  ('Barristan Selmy', 'CH_19'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Janos Slynt', 'CH_114'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Lord Varys', 'CH_177'),
#  ('Meryn Trant', 'CH_211'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Royal Steward', 'CH_295'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Eddard Stark', 'CH_59'),
#  ('Lord Varys', 'CH_177'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Joyeuse Erenford', 'CH_127'),
#  ('Ryger Rivers', 'CH_296'),
#  ('Stevron Frey', 'CH_323'),
#  ('Walder Frey', 'CH_357'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Walder Frey', 'CH_357'),
#  ('Jeor Mormont', 'CH_118'),
#  ('Jon Snow', 'CH_123'),
#  ('Jon Snow', 'CH_123'),
#  ('Grenn', 'CH_89'),
#  ('Jon Snow', 'CH_123'),
#  ('Pypar', 'CH_262'),
#  ('Rast', 'CH_271'),
#  ('Samwell Tarly', 'CH_298'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Jon Snow', 'CH_123'),
#  ('Maester Aemon', 'CH_186'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Khal Drogo', 'CH_133'),
#  ('Qotho', 'CH_265'),
#  ('Rakharo', 'CH_268'),
#  ('Kevan Lannister', 'CH_132'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Tywin Lannister', 'CH_350'),
#  ('Bronn', 'CH_32'),
#  ('Shae', 'CH_309'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Daenerys Targaryen', 'CH_44'),
#  ('Doreah', 'CH_53'),
#  ('Irri', 'CH_109'),
#  ('Jorah Mormont', 'CH_125'),
#  ('Khal Drogo', 'CH_133'),
#  ('Mirri Maz Duur', 'CH_215'),
#  ('Qotho', 'CH_265'),
#  ('Rakharo', 'CH_268'),
#  ('Bronn', 'CH_32'),
#  ('Shae', 'CH_309'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Shae', 'CH_309'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Chella', 'CH_514'),
#  ('Shagga', 'CH_310'),
#  ('Timett', 'CH_340'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Bronn', 'CH_32'),
#  ('Tyrion Lannister', 'CH_349'),
#  ('Tywin Lannister', 'CH_350'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Arya Stark', 'CH_15'),
#  ("King's Landing Baker", 'CH_515'),
#  ('Street Urchin', 'CH_516'),
#  ('Arya Stark', 'CH_15'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Eddard Stark', 'CH_59'),
#  ('Grand Maester Pycelle', 'CH_78'),
#  ('Ilyn Payne', 'CH_108'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Lord Varys', 'CH_177'),
#  ('Petyr Baelish', 'CH_257'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Yoren', 'CH_380'),
#  ('Arya Stark', 'CH_15'),
#  ('Eddard Stark', 'CH_59'),
#  ('Ilyn Payne', 'CH_108'),
#  ('Lord Varys', 'CH_177'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Yoren', 'CH_380'),
#  ('Arya Stark', 'CH_15'),
#  ('Yoren', 'CH_380'),
#  ('Bran Stark', 'CH_29'),
#  ('Three-Eyed Raven', 'CH_339'),
#  ('Bran Stark', 'CH_29'),
#  ('Hodor', 'CH_102'),
#  ('Osha', 'CH_253'),
#  ('Bran Stark', 'CH_29'),
#  ('Osha', 'CH_253'),
#  ('Rickon Stark', 'CH_285'),
#  ('Shaggydog', 'CH_311'),
#  ('Bran Stark', 'CH_29'),
#  ('Maester Luwin', 'CH_188'),
#  ('Osha', 'CH_253'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Robb Stark', 'CH_286'),
#  ('Cersei Lannister', 'CH_38'),
#  ('Ilyn Payne', 'CH_108'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Marillion', 'CH_201'),
#  ('Meryn Trant', 'CH_211'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Eddard Stark', 'CH_59'),
#  ('Joffrey Baratheon', 'CH_120'),
#  ('Meryn Trant', 'CH_211'),
#  ('Sandor Clegane', 'CH_299'),
#  ('Sansa Stark', 'CH_300'),
#  ('Septa Mordane', 'CH_303'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Greatjon Umber', 'CH_86'),
#  ('Jonos Bracken', 'CH_124'),
#  ('Rickard Karstark', 'CH_283'),
#  ('Robb Stark', 'CH_286'),
#  ('Rodrik Cassel', 'CH_290'),
#  ('Theon Greyjoy', 'CH_336'),
#  ('Catelyn Stark', 'CH_36'),
#  ('Jaime Lannister', 'CH_113'),
#  ('Cersei Lannister', 'CH_38'),
#  ...]

# %%
# %%sql UPDATE scenes_characters AS SC
#     JOIN character_ids AS IDTable
#     ON SC.characterName = IDTable.characterName
#     SET SC.character_id = IDTable.character_id;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
#     ADD INDEX `character_id_idx` (`character_id` ASC) VISIBLE;
#
#     ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
#     ADD CONSTRAINT `sc_to_character`
#       FOREIGN KEY (`character_id`)
#       REFERENCES `W4111GoTSolutionClean`.`characters` (`character_id`)
#       ON DELETE NO ACTION
#       ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# 12114 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
#     ADD INDEX `scc_to_sc_idx` (`seasonNum` ASC, `episodeNum` ASC, `sceneNo` ASC) VISIBLE;
#
#     ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
#     ADD CONSTRAINT `scc_to_sc`
#       FOREIGN KEY (`seasonNum` , `episodeNum` , `sceneNo`)
#       REFERENCES `W4111GoTSolutionClean`.`scenes` (`seasonNum` , `episodeNum` , `sceneNo`)
#       ON DELETE NO ACTION
#       ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# 12114 rows affected.
# []

# %%
# %sql DESCRIBE scenes_characters;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 6 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'MUL', None, '')]

# %% [markdown]
# ## Task 4
#
# ### Views

# %% [markdown]
# #### Character Interactions
#
# - ```Characters``` interacted if they appeared in the same ```scene.```
#
#
# - Create the following view:
#     - ```characterName_1```
#     - ```character_id_1```
#     - ```characterName_2```
#     - ```character_id_2```
#     - ```scene_count,``` number of scenes containing both ```characters.```
#     - Order by ```scene_count``` descending.
#
# - Each pair should appear only once, that is the table should not contain two rows of the form:
#     - ```character_1, character_2, scene_count```
#     - ```character_2, character_1, scene_count```
#
#
# <u>Answer:</u>

# %%
# %%sql CREATE VIEW character_interaction AS
#     SELECT DISTINCT character_1, character_2, COUNT(*) AS scene_count
#     FROM (
#         SELECT sc.seasonNum, sc.episodeNum, sc.sceneNo,
#             sc.characterName AS character_1,
#             sc1.characterName AS character_2
#         FROM scenes_characters AS sc
#         JOIN scenes_characters AS sc1
#         ON sc.seasonNum=sc1.seasonNum AND sc.episodeNum=sc1.episodeNum AND sc.sceneNo=sc1.sceneNo
#     ) AS F
#     WHERE F.character_1 != F.character_2 AND F.character_1 > F.character_2
#     GROUP BY character_1, character_2
#     ORDER BY scene_count DESC;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM `W4111GoTSolutionClean`.`character_interaction`;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 4236 rows affected.
# [('Drogon', 'Daenerys Targaryen', 172),
#  ('Jorah Mormont', 'Daenerys Targaryen', 148),
#  ('Tormund Giantsbane', 'Jon Snow', 145),
#  ('Tyrion Lannister', 'Lord Varys', 141),
#  ('Jon Snow', 'Davos Seaworth', 136),
#  ('Missandei', 'Daenerys Targaryen', 131),
#  ('Jon Snow', 'Daenerys Targaryen', 119),
#  ('Tyrion Lannister', 'Daenerys Targaryen', 116),
#  ('Tyrion Lannister', 'Missandei', 97),
#  ('Jaime Lannister', 'Brienne of Tarth', 91),
#  ('Missandei', 'Grey Worm', 86),
#  ('Tyrion Lannister', 'Jon Snow', 82),
#  ('Tyrion Lannister', 'Cersei Lannister', 82),
#  ('Grey Worm', 'Daenerys Targaryen', 82),
#  ('Jaime Lannister', 'Cersei Lannister', 81),
#  ('Jon Snow', 'Eddison Tollett', 81),
#  ('Podrick Payne', 'Brienne of Tarth', 81),
#  ('Samwell Tarly', 'Jon Snow', 80),
#  ('Tyrion Lannister', 'Sansa Stark', 80),
#  ('Hodor', 'Bran Stark', 76),
#  ('Tyrion Lannister', 'Podrick Payne', 75),
#  ('Tyrion Lannister', 'Jaime Lannister', 74),
#  ('Tyrion Lannister', 'Davos Seaworth', 70),
#  ('Meera Reed', 'Bran Stark', 68),
#  ('Sandor Clegane', 'Arya Stark', 67),
#  ('Gregor Clegane', 'Cersei Lannister', 67),
#  ('Tommen Baratheon', 'Cersei Lannister', 65),
#  ('Tyrion Lannister', 'Grey Worm', 65),
#  ('Sansa Stark', 'Jon Snow', 64),
#  ('Rhaegal', 'Drogon', 64),
#  ('Missandei', 'Jorah Mormont', 64),
#  ('Missandei', 'Lord Varys', 64),
#  ('Lord Varys', 'Daenerys Targaryen', 64),
#  ('Samwell Tarly', 'Gilly', 62),
#  ('Daenerys Targaryen', 'Barristan Selmy', 62),
#  ('Joffrey Baratheon', 'Cersei Lannister', 60),
#  ('Rhaegal', 'Daenerys Targaryen', 59),
#  ('Tyrion Lannister', 'Bronn', 59),
#  ('Sansa Stark', 'Petyr Baelish', 58),
#  ('Qyburn', 'Cersei Lannister', 58),
#  ('Tywin Lannister', 'Cersei Lannister', 57),
#  ('Tyrion Lannister', 'Jorah Mormont', 57),
#  ('Daenerys Targaryen', 'Daario Naharis', 56),
#  ('Jorah Mormont', 'Jon Snow', 56),
#  ('Sandor Clegane', 'Beric Dondarrion', 53),
#  ('Tyrion Lannister', 'Joffrey Baratheon', 52),
#  ('Sansa Stark', 'Joffrey Baratheon', 51),
#  ('Meera Reed', 'Hodor', 51),
#  ('Viserion', 'Rhaegal', 50),
#  ('Gendry', 'Arya Stark', 50),
#  ('Margaery Tyrell', 'Cersei Lannister', 50),
#  ('Jaime Lannister', 'Bronn', 50),
#  ('Tormund Giantsbane', 'Beric Dondarrion', 50),
#  ('Lord Varys', 'Jon Snow', 49),
#  ('Sansa Stark', 'Cersei Lannister', 48),
#  ('Ygritte', 'Jon Snow', 48),
#  ('Grand Maester Pycelle', 'Cersei Lannister', 47),
#  ('Tywin Lannister', 'Tyrion Lannister', 47),
#  ('Gilly', 'Baby Sam', 47),
#  ('Sansa Stark', 'Brienne of Tarth', 47),
#  ('Qyburn', 'Gregor Clegane', 47),
#  ('Missandei', 'Jon Snow', 46),
#  ('Jon Snow', 'Grenn', 45),
#  ('Samwell Tarly', 'Eddison Tollett', 45),
#  ('Jorah Mormont', 'Barristan Selmy', 45),
#  ('Tyrion Lannister', 'Brienne of Tarth', 45),
#  ('Robb Stark', 'Catelyn Stark', 44),
#  ('Jojen Reed', 'Bran Stark', 44),
#  ('Mace Tyrell', 'Cersei Lannister', 44),
#  ('Sandor Clegane', 'Jorah Mormont', 44),
#  ('Jon Snow', 'Grey Worm', 44),
#  ('Missandei', 'Barristan Selmy', 43),
#  ('Lord Varys', 'Davos Seaworth', 43),
#  ('Tormund Giantsbane', 'Sandor Clegane', 43),
#  ('Sansa Stark', 'Arya Stark', 42),
#  ('Sandor Clegane', 'Jon Snow', 42),
#  ('Davos Seaworth', 'Brienne of Tarth', 42),
#  ('Tormund Giantsbane', 'Davos Seaworth', 42),
#  ('Lord Varys', 'Grey Worm', 42),
#  ('Missandei', 'Davos Seaworth', 42),
#  ('Grenn', 'Eddison Tollett', 41),
#  ('Jon Snow', 'Brienne of Tarth', 41),
#  ('Jon Snow', 'Drogon', 41),
#  ('Viserion', 'Daenerys Targaryen', 40),
#  ('Viserion', 'Drogon', 40),
#  ('Lord Varys', 'Cersei Lannister', 40),
#  ('Margaery Tyrell', 'Joffrey Baratheon', 39),
#  ('Missandei', 'Daario Naharis', 39),
#  ('Tormund Giantsbane', 'Eddison Tollett', 39),
#  ('Davos Seaworth', 'Daenerys Targaryen', 39),
#  ('Three-Eyed Raven', 'Bran Stark', 38),
#  ('Melisandre', 'Davos Seaworth', 38),
#  ('Talisa Maegyr', 'Robb Stark', 38),
#  ('Samwell Tarly', 'Baby Sam', 38),
#  ('Jon Snow', 'Alliser Thorne', 37),
#  ('Margaery Tyrell', 'Loras Tyrell', 37),
#  ('Meera Reed', 'Jojen Reed', 37),
#  ('Rhaegal', 'Jon Snow', 37),
#  ('Jon Snow', 'Ghost', 36),
#  ('Tormund Giantsbane', 'Jorah Mormont', 36),
#  ('Summer', 'Bran Stark', 35),
#  ('Stannis Baratheon', 'Davos Seaworth', 35),
#  ('Tyrion Lannister', 'Drogon', 35),
#  ('Jon Snow', 'Bran Stark', 34),
#  ("Jaqen H'ghar", 'Arya Stark', 34),
#  ('Jojen Reed', 'Hodor', 34),
#  ('Sansa Stark', 'Davos Seaworth', 34),
#  ('Jorah Mormont', 'Beric Dondarrion', 34),
#  ('Sansa Stark', 'Lord Varys', 33),
#  ('Yara Greyjoy', 'Theon Greyjoy', 33),
#  ('Shae', 'Sansa Stark', 33),
#  ('Ygritte', 'Tormund Giantsbane', 33),
#  ('Sandor Clegane', 'Gendry', 33),
#  ('Thoros of Myr', 'Beric Dondarrion', 33),
#  ('Tommen Baratheon', 'Margaery Tyrell', 33),
#  ('Tormund Giantsbane', 'Sansa Stark', 33),
#  ('Jon Snow', 'Beric Dondarrion', 33),
#  ('Theon Greyjoy', 'Bran Stark', 32),
#  ('Tyrion Lannister', 'Bran Stark', 32),
#  ('Stannis Baratheon', 'Melisandre', 32),
#  ('Olenna Tyrell', 'Margaery Tyrell', 32),
#  ('Jorah Mormont', 'Grey Worm', 32),
#  ('Jorah Mormont', 'Daario Naharis', 32),
#  ('Sansa Stark', 'Podrick Payne', 32),
#  ('Podrick Payne', 'Jaime Lannister', 32),
#  ('Tywin Lannister', 'Mace Tyrell', 32),
#  ('Margaery Tyrell', 'Mace Tyrell', 32),
#  ('Tyrion Lannister', 'Qhono', 32),
#  ('Sansa Stark', 'Sandor Clegane', 31),
#  ('Tommen Baratheon', 'Joffrey Baratheon', 31),
#  ('Tyrion Lannister', 'Sandor Clegane', 31),
#  ('Osha', 'Bran Stark', 31),
#  ('Tyrion Lannister', 'Shae', 31),
#  ('Thoros of Myr', 'Sandor Clegane', 31),
#  ('Olly', 'Jon Snow', 31),
#  ('Qhono', 'Daenerys Targaryen', 31),
#  ('Sansa Stark', 'Bran Stark', 30),
#  ('Sandor Clegane', 'Joffrey Baratheon', 30),
#  ('Samwell Tarly', 'Grenn', 30),
#  ('Tywin Lannister', 'Jaime Lannister', 30),
#  ('Tormund Giantsbane', 'Brienne of Tarth', 30),
#  ('Jorah Mormont', 'Davos Seaworth', 30),
#  ('Tommen Baratheon', 'Sansa Stark', 29),
#  ('Tywin Lannister', 'Joffrey Baratheon', 29),
#  ('Lord Varys', 'Brienne of Tarth', 29),
#  ('Yohn Royce', 'Sansa Stark', 29),
#  ('Tormund Giantsbane', 'Podrick Payne', 29),
#  ('Tormund Giantsbane', 'Gendry', 29),
#  ('Qyburn', 'Jaime Lannister', 28),
#  ('Grey Worm', 'Barristan Selmy', 28),
#  ('Qhono', 'Jon Snow', 28),
#  ('Grey Worm', 'Davos Seaworth', 28),
#  ('Theon Greyjoy', 'Sansa Stark', 27),
#  ('Tywin Lannister', 'Margaery Tyrell', 27),
#  ('Thoros of Myr', 'Gendry', 27),
#  ('Tyrion Lannister', 'Mace Tyrell', 27),
#  ('Hizdahr zo Loraq', 'Daenerys Targaryen', 27),
#  ('Missandei', 'Brienne of Tarth', 27),
#  ('Sansa Stark', 'Daenerys Targaryen', 27),
#  ('Theon Greyjoy', 'Jon Snow', 26),
#  ('Lord Varys', 'Jaime Lannister', 26),
#  ('Mace Tyrell', 'Jaime Lannister', 26),
#  ('Jaime Lannister', 'Gregor Clegane', 26),
#  ('Melisandre', 'Jon Snow', 26),
#  ('Lord Varys', 'Jorah Mormont', 26),
#  ('Jaime Lannister', 'Daenerys Targaryen', 26),
#  ('Daenerys Targaryen', 'Brienne of Tarth', 26),
#  ('Jorah Mormont', 'Drogon', 25),
#  ('Osha', 'Hodor', 25),
#  ('Tywin Lannister', 'Tommen Baratheon', 25),
#  ('Sansa Stark', 'Margaery Tyrell', 25),
#  ('Theon Greyjoy', 'Ramsay Snow', 25),
#  ('Olenna Tyrell', 'Cersei Lannister', 25),
#  ('Gendry', 'Beric Dondarrion', 25),
#  ('Tyrion Lannister', 'Oberyn Martell', 25),
#  ('Mace Tyrell', 'Grand Maester Pycelle', 25),
#  ('Tormund Giantsbane', 'Samwell Tarly', 25),
#  ('Margaery Tyrell', 'High Sparrow', 25),
#  ('Daenerys Targaryen', 'Bran Stark', 25),
#  ('Jon Snow', 'Gendry', 25),
#  ('Jorah Mormont', 'Brienne of Tarth', 25),
#  ('Rickon Stark', 'Bran Stark', 24),
#  ('Summer', 'Hodor', 24),
#  ('Tyrion Lannister', 'Theon Greyjoy', 24),
#  ('Tyrion Lannister', 'Tommen Baratheon', 24),
#  ('Tyrion Lannister', 'Grand Maester Pycelle', 24),
#  ('Tyrion Lannister', 'Margaery Tyrell', 24),
#  ('Tommen Baratheon', 'Mace Tyrell', 24),
#  ('Brienne of Tarth', 'Bran Stark', 24),
#  ('Lord Varys', 'Grand Maester Pycelle', 23),
#  ('Meryn Trant', 'Joffrey Baratheon', 23),
#  ('Rickon Stark', 'Osha', 23),
#  ('Hot Pie', 'Arya Stark', 23),
#  ('Loras Tyrell', 'Cersei Lannister', 23),
#  ('Qhono', 'Davos Seaworth', 23),
#  ('Qhono', 'Missandei', 23),
#  ('Grey Worm', 'Brienne of Tarth', 23),
#  ('Jon Snow', 'Arya Stark', 22),
#  ('Rodrik Cassel', 'Catelyn Stark', 22),
#  ('Jon Snow', 'Jaime Lannister', 22),
#  ('Khal Drogo', 'Daenerys Targaryen', 22),
#  ('Hot Pie', 'Gendry', 22),
#  ('Daario Naharis', 'Barristan Selmy', 22),
#  ('Tyrion Lannister', 'Gregor Clegane', 22),
#  ('Podrick Payne', 'Jon Snow', 22),
#  ('Lyanna Mormont', 'Davos Seaworth', 22),
#  ('Ramsay Snow', 'Jon Snow', 22),
#  ('Yohn Royce', 'Davos Seaworth', 22),
#  ('Yohn Royce', 'Brienne of Tarth', 22),
#  ('Euron Greyjoy', 'Cersei Lannister', 22),
#  ('Viserion', 'Jon Snow', 22),
#  ('Viserion', 'The Night King', 22),
#  ('Jaime Lannister', 'Davos Seaworth', 22),
#  ('Bran Stark', 'Arya Stark', 21),
#  ('Theon Greyjoy', 'Robb Stark', 21),
#  ('Samwell Tarly', 'Ghost', 21),
#  ('Talisa Maegyr', 'Catelyn Stark', 21),
#  ('Grey Worm', 'Daario Naharis', 21),
#  ('Margaery Tyrell', 'Jaime Lannister', 21),
#  ('Oberyn Martell', 'Cersei Lannister', 21),
#  ('Tywin Lannister', 'Oberyn Martell', 21),
#  ('Olly', 'Alliser Thorne', 21),
#  ('Hizdahr zo Loraq', 'Daario Naharis', 21),
#  ('Jorah Mormont', 'Gendry', 21),
#  ('Yohn Royce', 'Bran Stark', 21),
#  ('Samwell Tarly', 'Brienne of Tarth', 21),
#  ('Rickon Stark', 'Hodor', 20),
#  ('Sansa Stark', 'Jaime Lannister', 20),
#  ('Pypar', 'Jon Snow', 20),
#  ('Samwell Tarly', 'Alliser Thorne', 20),
#  ('Roose Bolton', 'Robb Stark', 20),
#  ('Tywin Lannister', 'Grand Maester Pycelle', 20),
#  ('Sansa Stark', 'Olenna Tyrell', 20),
#  ('Missandei', 'Drogon', 20),
#  ('Tyrion Lannister', 'Olenna Tyrell', 20),
#  ('Gendry', 'Davos Seaworth', 20),
#  ('Oberyn Martell', 'Ellaria Sand', 20),
#  ('Jon Snow', 'Janos Slynt', 20),
#  ('Obara Sand', 'Nymeria Sand', 20),
#  ('Lyanna Mormont', 'Jon Snow', 20),
#  ('Gregor Clegane', 'Euron Greyjoy', 20),
#  ('Thoros of Myr', 'Jorah Mormont', 20),
#  ('Davos Seaworth', 'Bran Stark', 20),
#  ('Grey Worm', 'Bran Stark', 20),
#  ('Jaime Lannister', 'Bran Stark', 19),
#  ('Doreah', 'Daenerys Targaryen', 19),
#  ('Petyr Baelish', 'Lord Varys', 19),
#  ('Sandor Clegane', 'Gregor Clegane', 19),
#  ('Othell Yarwyck', 'Jon Snow', 19),
#  ('Sandor Clegane', 'Lord Varys', 19),
#  ('Podrick Payne', 'Bronn', 19),
#  ('Thoros of Myr', 'Arya Stark', 19),
#  ('Grey Worm', 'Drogon', 19),
#  ('Janos Slynt', 'Alliser Thorne', 19),
#  ('Oberyn Martell', 'Mace Tyrell', 19),
#  ('Eddison Tollett', 'Alliser Thorne', 19),
#  ('The Waif', 'Arya Stark', 19),
#  ('Wun Wun', 'Jon Snow', 19),
#  ('Wun Wun', 'Tormund Giantsbane', 19),
#  ('Theon Greyjoy', 'Brienne of Tarth', 19),
#  ('Yohn Royce', 'Jon Snow', 19),
#  ('Theon Greyjoy', 'Lord Varys', 19),
#  ('Theon Greyjoy', 'Missandei', 19),
#  ('Theon Greyjoy', 'Davos Seaworth', 19),
#  ('Thoros of Myr', 'Jon Snow', 19),
#  ('Tormund Giantsbane', 'Thoros of Myr', 19),
#  ('Yohn Royce', 'Grey Worm', 19),
#  ('Irri', 'Daenerys Targaryen', 18),
#  ('Rast', 'Grenn', 18),
#  ('Samwell Tarly', 'Pypar', 18),
#  ('Meryn Trant', 'Cersei Lannister', 18),
#  ('Beric Dondarrion', 'Arya Stark', 18),
#  ('Mace Tyrell', 'Loras Tyrell', 18),
#  ('Missandei', 'Hizdahr zo Loraq', 18),
#  ('Olly', 'Eddison Tollett', 18),
#  ('Eddison Tollett', 'Davos Seaworth', 18),
#  ('Samwell Tarly', 'Davos Seaworth', 18),
#  ('Tyene Sand', 'Ellaria Sand', 18),
#  ('The Night King', 'Jon Snow', 18),
#  ('Sansa Stark', 'Lyanna Mormont', 18),
#  ('Qhono', 'Lord Varys', 18),
#  ('Qhono', 'Jorah Mormont', 18),
#  ('Missandei', 'Cersei Lannister', 18),
#  ('Missandei', 'Gregor Clegane', 18),
#  ('Missandei', 'Jaime Lannister', 18),
#  ('Yohn Royce', 'Tyrion Lannister', 18),
#  ('Jaime Lannister', 'Grey Worm', 18),
#  ('Tormund Giantsbane', 'Jaime Lannister', 18),
#  ('Joffrey Baratheon', 'Jaime Lannister', 17),
#  ('Tommen Baratheon', 'Jaime Lannister', 17),
#  ('Rhaegal', 'Jorah Mormont', 17),
#  ('Petyr Baelish', 'Eddard Stark', 17),
#  ('Jon Snow', 'Jeor Mormont', 17),
#  ('Pypar', 'Grenn', 17),
#  ('Joffrey Baratheon', 'Grand Maester Pycelle', 17),
#  ('Tommen Baratheon', 'Grand Maester Pycelle', 17),
#  ('Samwell Tarly', 'Jeor Mormont', 17),
#  ('Podrick Payne', 'Lord Varys', 17),
#  ('Summer', 'Meera Reed', 17),
#  ('Olenna Tyrell', 'Joffrey Baratheon', 17),
#  ('Samwell Tarly', 'Bran Stark', 17),
#  ('Roose Bolton', 'Ramsay Snow', 17),
#  ('Lord Varys', 'Gregor Clegane', 17),
#  ('Stannis Baratheon', 'Jon Snow', 17),
#  ('Sandor Clegane', 'Brienne of Tarth', 17),
#  ('Tormund Giantsbane', 'Ramsay Snow', 17),
#  ('Yohn Royce', 'Lyanna Mormont', 17),
#  ('Qyburn', 'Euron Greyjoy', 17),
#  ('Tormund Giantsbane', 'Daenerys Targaryen', 17),
#  ('Theon Greyjoy', 'Jorah Mormont', 17),
#  ('Jorah Mormont', 'Jaime Lannister', 17),
#  ('Sansa Stark', 'Missandei', 17),
#  ('Samwell Tarly', 'Jaime Lannister', 17),
#  ('Sandor Clegane', 'Cersei Lannister', 16),
#  ('Othell Yarwyck', 'Alliser Thorne', 16),
#  ('Theon Greyjoy', 'Dagmer Cleftjaw', 16),
#  ('Tywin Lannister', 'Sansa Stark', 16),
#  ('Locke', 'Jaime Lannister', 16),
#  ('Tywin Lannister', 'Olenna Tyrell', 16),
#  ('Oberyn Martell', 'Jaime Lannister', 16),
#  ('White Walker', 'The Night King', 16),
#  ('Samwell Tarly', 'Olly', 16),
#  ('Yohn Royce', 'Petyr Baelish', 16),
#  ('Leaf', 'Bran Stark', 16),
#  ('Brienne of Tarth', 'Arya Stark', 16),
#  ('Sansa Stark', 'Ramsay Snow', 16),
#  ('Samwell Tarly', 'Jorah Mormont', 16),
#  ('Sandor Clegane', 'Davos Seaworth', 16),
#  ('Sandor Clegane', 'Daenerys Targaryen', 16),
#  ('Theon Greyjoy', 'Qhono', 16),
#  ('Missandei', 'Euron Greyjoy', 16),
#  ('Tyrion Lannister', 'Qyburn', 16),
#  ('Daenerys Targaryen', 'Cersei Lannister', 16),
#  ('Yohn Royce', 'Daenerys Targaryen', 16),
#  ('Samwell Tarly', 'Gendry', 16),
#  ('Theon Greyjoy', 'Rodrik Cassel', 15),
#  ('Jory Cassel', 'Eddard Stark', 15),
#  ('Myrcella Baratheon', 'Jaime Lannister', 15),
#  ('Petyr Baelish', 'Grand Maester Pycelle', 15),
#  ('Sansa Stark', 'Meryn Trant', 15),
#  ('Kovarro', 'Daenerys Targaryen', 15),
#  ('Sandor Clegane', 'Podrick Payne', 15),
#  ('Tywin Lannister', 'Lord Varys', 15),
#  ('Orell', 'Jon Snow', 15),
#  ('Edmure Tully', 'Catelyn Stark', 15),
#  ('Robb Stark', 'Edmure Tully', 15),
#  ('Tommen Baratheon', 'Olenna Tyrell', 15),
#  ('Tyene Sand', 'Nymeria Sand', 15),
#  ('Tyene Sand', 'Obara Sand', 15),
#  ('Lyanna Mormont', 'Brienne of Tarth', 15),
#  ('Podrick Payne', 'Davos Seaworth', 15),
#  ('Sandor Clegane', 'Missandei', 15),
#  ('Qhono', 'Brienne of Tarth', 15),
#  ('Gregor Clegane', 'Daenerys Targaryen', 15),
#  ('Daenerys Targaryen', 'Arya Stark', 15),
#  ('Sansa Stark', 'Grey Worm', 15),
#  ('Lord Varys', 'Bran Stark', 15),
#  ('Tyrion Lannister', 'Samwell Tarly', 15),
#  ('Samwell Tarly', 'Podrick Payne', 15),
#  ('Rodrik Cassel', 'Robb Stark', 14),
#  ('Theon Greyjoy', 'Maester Luwin', 14),
#  ('Theon Greyjoy', 'Sandor Clegane', 14),
#  ('Jeor Mormont', 'Grenn', 14),
#  ('Rakharo', 'Daenerys Targaryen', 14),
#  ('Samwell Tarly', 'Rast', 14),
#  ('Petyr Baelish', 'Cersei Lannister', 14),
#  ('Sansa Stark', 'Grand Maester Pycelle', 14),
#  ('Lord Varys', 'Joffrey Baratheon', 14),
#  ('Roose Bolton', 'Catelyn Stark', 14),
#  ('Podrick Payne', 'Joffrey Baratheon', 14),
#  ('Mance Rayder', 'Jon Snow', 14),
#  ('Ygritte', 'Orell', 14),
#  ('Edmure Tully', 'Brynden Tully', 14),
#  ('Mace Tyrell', 'Joffrey Baratheon', 14),
#  ('Qyburn', 'Grand Maester Pycelle', 14),
#  ('Mace Tyrell', 'Kevan Lannister', 14),
#  ('Young Ned Stark', 'Bran Stark', 14),
#  ('The Night King', 'Bran Stark', 14),
#  ('Qyburn', 'Lord Varys', 14),
#  ('Qyburn', 'Missandei', 14),
#  ('Tyrion Lannister', 'Euron Greyjoy', 14),
#  ('Euron Greyjoy', 'Daenerys Targaryen', 14),
#  ('Qyburn', 'Daenerys Targaryen', 14),
#  ('Missandei', 'Bran Stark', 14),
#  ('Yohn Royce', 'Lord Varys', 14),
#  ('Davos Seaworth', 'Arya Stark', 14),
#  ('Samwell Tarly', 'Grey Worm', 14),
#  ('Eddard Stark', 'Arya Stark', 13),
#  ('Robb Stark', 'Bran Stark', 13),
#  ('Maester Luwin', 'Bran Stark', 13),
#  ('Robert Baratheon', 'Eddard Stark', 13),
#  ('Viserion', 'Jorah Mormont', 13),
#  ('Irri', 'Doreah', 13),
#  ('Jorah Mormont', 'Doreah', 13),
#  ('Grenn', 'Alliser Thorne', 13),
#  ('Rakharo', 'Jorah Mormont', 13),
#  ('Walder Frey', 'Catelyn Stark', 13),
#  ('Tyrion Lannister', 'Meryn Trant', 13),
#  ('Catelyn Stark', 'Brienne of Tarth', 13),
#  ('Talisa Maegyr', 'Roose Bolton', 13),
#  ('High Septon', 'Cersei Lannister', 13),
#  ('Tywin Lannister', 'Loras Tyrell', 13),
#  ('Margaery Tyrell', 'Grand Maester Pycelle', 13),
#  ('Tormund Giantsbane', 'Orell', 13),
#  ('Summer', 'Jojen Reed', 13),
#  ('Osha', 'Meera Reed', 13),
#  ('Arya Stark', 'Anguy', 13),
#  ('Catelyn Stark', 'Brynden Tully', 13),
#  ('Tyrion Lannister', 'Ellaria Sand', 13),
#  ('Ygritte', 'Styr', 13),
#  ('Olenna Tyrell', 'Mace Tyrell', 13),
#  ('Janos Slynt', 'Eddison Tollett', 13),
#  ('Ramsay Snow', 'Davos Seaworth', 13),
#  ('Theon Greyjoy', 'Daenerys Targaryen', 13),
#  ('Yohn Royce', 'Arya Stark', 13),
#  ('Lord Varys', 'Euron Greyjoy', 13),
#  ('Yohn Royce', 'Missandei', 13),
#  ('Gendry', 'Brienne of Tarth', 13),
#  ('Theon Greyjoy', 'Jaime Lannister', 12),
#  ('Khal Drogo', 'Jorah Mormont', 12),
#  ('Jorah Mormont', 'Irri', 12),
#  ('Lord Varys', 'Eddard Stark', 12),
#  ('Sansa Stark', 'Loras Tyrell', 12),
#  ('Yoren', 'Arya Stark', 12),
#  ('Jon Snow', 'Gilly', 12),
#  ('Matthos Seaworth', 'Davos Seaworth', 12),
#  ('Stannis Baratheon', 'Selyse Baratheon', 12),
#  ('Xaro Xhoan Daxos', 'Daenerys Targaryen', 12),
#  ('Joffrey Baratheon', 'High Septon', 12),
#  ('Osha', 'Jojen Reed', 12),
#  ('Thoros of Myr', 'Anguy', 12),
#  ('Locke', 'Brienne of Tarth', 12),
#  ('Robb Stark', 'Brynden Tully', 12),
#  ('Talisa Maegyr', 'Edmure Tully', 12),
#  ('Qyburn', 'Brienne of Tarth', 12),
#  ('Tyrion Lannister', 'Loras Tyrell', 12),
#  ('Tormund Giantsbane', 'Styr', 12),
#  ('Samwell Tarly', 'Janos Slynt', 12),
#  ('Olly', 'Janos Slynt', 12),
#  ('Othell Yarwyck', 'Olly', 12),
#  ('Doran Martell', 'Areo Hotah', 12),
#  ('Septa Unella', 'Cersei Lannister', 12),
#  ('Tyrion Lannister', 'Daario Naharis', 12),
#  ('Smalljon Umber', 'Ramsay Snow', 12),
#  ('Podrick Payne', 'Bran Stark', 12),
#  ('Lyanna Mormont', 'Bran Stark', 12),
#  ('Podrick Payne', 'Daenerys Targaryen', 12),
#  ('Podrick Payne', 'Grey Worm', 12),
#  ('Yohn Royce', 'Jaime Lannister', 12),
#  ('Podrick Payne', 'Gendry', 12),
#  ('Sansa Stark', 'Eddard Stark', 11),
#  ('Theon Greyjoy', 'Catelyn Stark', 11),
#  ('Rast', 'Jon Snow', 11),
#  ('Rast', 'Jeor Mormont', 11),
#  ('Maester Aemon', 'Jon Snow', 11),
#  ('Petyr Baelish', 'Arya Stark', 11),
#  ('Tommen Baratheon', 'Loras Tyrell', 11),
#  ('Samwell Tarly', 'Maester Aemon', 11),
#  ('Samwell Tarly', 'Othell Yarwyck', 11),
#  ('Sandor Clegane', 'Meryn Trant', 11),
#  ('Sansa Stark', 'Dontos Hollard', 11),
#  ('Kovarro', 'Jorah Mormont', 11),
#  ('Selyse Baratheon', 'Melisandre', 11),
#  ('Petyr Baelish', 'Brienne of Tarth', 11),
#  ('Margaery Tyrell', 'High Septon', 11),
#  ('Sansa Stark', 'Mace Tyrell', 11),
#  ('Mace Tyrell', 'Lord Varys', 11),
#  ('Oberyn Martell', 'Margaery Tyrell', 11),
#  ('Podrick Payne', 'Arya Stark', 11),
#  ('Trystane Martell', 'Myrcella Baratheon', 11),
#  ('Bowen Marsh', 'Alliser Thorne', 11),
#  ('Ghost', 'Davos Seaworth', 11),
#  ('Tyrion Lannister', 'Rhaegal', 11),
#  ('Yara Greyjoy', 'Euron Greyjoy', 11),
#  ('Izembaro', 'Bobono', 11),
#  ('Lord Varys', 'Drogon', 11),
#  ('Sandor Clegane', 'Qhono', 11),
#  ('Podrick Payne', 'Missandei', 11),
#  ('Lyanna Mormont', 'Jorah Mormont', 11),
#  ('Lyanna Mormont', 'Grey Worm', 11),
#  ('Samwell Tarly', 'Daenerys Targaryen', 11),
#  ('Grey Worm', 'Arya Stark', 11),
#  ('Tyrion Lannister', 'Arya Stark', 11),
#  ('Tyrion Lannister', 'Tormund Giantsbane', 11),
#  ('Eddard Stark', 'Catelyn Stark', 10),
#  ('Viserys Targaryen', 'Daenerys Targaryen', 10),
#  ('Sansa Stark', 'Ilyn Payne', 10),
#  ('Grand Maester Pycelle', 'Eddard Stark', 10),
#  ('Pypar', 'Alliser Thorne', 10),
#  ('Rast', 'Pypar', 10),
#  ('Gregor Clegane', 'Grand Maester Pycelle', 10),
#  ('Lord Varys', 'Arya Stark', 10),
#  ('Joyeuse Erenford', 'Catelyn Stark', 10),
#  ('White Walker', 'Jon Snow', 10),
#  ('Jeor Mormont', 'Eddison Tollett', 10),
#  ('Podrick Payne', 'Cersei Lannister', 10),
#  ('Shae', 'Cersei Lannister', 10),
#  ('Lothar Frey', 'Edmure Tully', 10),
#  ('Ramsay Snow', 'Myranda', 10),
#  ('Walder Frey', 'Robb Stark', 10),
#  ('Walder Frey', 'Talisa Maegyr', 10),
#  ('Jaime Lannister', 'Ellaria Sand', 10),
#  ('Oberyn Martell', 'Grand Maester Pycelle', 10),
#  ('Oberyn Martell', 'Loras Tyrell', 10),
#  ('Olenna Tyrell', 'Jaime Lannister', 10),
#  ('Cersei Lannister', 'Brienne of Tarth', 10),
#  ('Janos Slynt', 'Grenn', 10),
#  ('Tormund Giantsbane', 'Alliser Thorne', 10),
#  ('Meera Reed', 'Leaf', 10),
#  ('Kevan Lannister', 'Cersei Lannister', 10),
#  ('Tormund Giantsbane', 'Melisandre', 10),
#  ('Jon Snow', 'Bowen Marsh', 10),
#  ('High Sparrow', 'Cersei Lannister', 10),
#  ('Othell Yarwyck', 'Bowen Marsh', 10),
#  ('Wun Wun', 'Eddison Tollett', 10),
#  ('Septa Unella', 'Margaery Tyrell', 10),
#  ('Three-Eyed Raven', 'Leaf', 10),
#  ('Tormund Giantsbane', 'Ghost', 10),
#  ('Lady Crane', 'Arya Stark', 10),
#  ('The Night King', 'Daenerys Targaryen', 10),
#  ('The Night King', 'Drogon', 10),
#  ('Randyll Tarly', 'Dickon Tarly', 10),
#  ('Mace Tyrell', 'High Sparrow', 10),
#  ('Sansa Stark', 'Robett Glover', 10),
#  ('Tormund Giantsbane', 'Lyanna Mormont', 10),
#  ('Wun Wun', 'Ramsay Snow', 10),
#  ('Yohn Royce', 'Robett Glover', 10),
#  ('Yohn Royce', 'Tormund Giantsbane', 10),
#  ('Yohn Royce', 'Podrick Payne', 10),
#  ('Jaime Lannister', 'Euron Greyjoy', 10),
#  ('Tyrion Lannister', 'Gendry', 10),
#  ('The Night King', 'Rhaegal', 10),
#  ('Lyanna Mormont', 'Daenerys Targaryen', 10),
#  ('Lyanna Mormont', 'Jaime Lannister', 10),
#  ('Samwell Tarly', 'Arya Stark', 10),
#  ('Sansa Stark', 'Samwell Tarly', 10),
#  ('Tormund Giantsbane', 'Grey Worm', 10),
#  ('Grey Worm', 'Gendry', 10),
#  ('Jaime Lannister', 'Gendry', 10),
#  ('Rickon Stark', 'Jon Snow', 9),
#  ('Septa Mordane', 'Sansa Stark', 9),
#  ('Eddard Stark', 'Cersei Lannister', 9),
#  ('Maester Luwin', 'Hodor', 9),
#  ('Sandor Clegane', 'Jaime Lannister', 9),
#  ('Theon Greyjoy', 'Cersei Lannister', 9),
#  ('Tommen Baratheon', 'Myrcella Baratheon', 9),
#  ('Renly Baratheon', 'Petyr Baelish', 9),
#  ('Rakharo', 'Irri', 9),
#  ('Loras Tyrell', 'Grand Maester Pycelle', 9),
#  ('Loras Tyrell', 'Joffrey Baratheon', 9),
#  ('Osha', 'Maester Luwin', 9),
#  ('Meryn Trant', 'Arya Stark', 9),
#  ('Walder Frey', 'Joyeuse Erenford', 9),
#  ('Lancel Lannister', 'Cersei Lannister', 9),
#  ('Tywin Lannister', 'Arya Stark', 9),
#  ('Ghost', 'Eddison Tollett', 9),
#  ('Tyrion Lannister', 'Hallyne', 9),
#  ('Margaery Tyrell', 'Lord Varys', 9),
#  ('Tormund Giantsbane', 'Mance Rayder', 9),
#  ('Gendry', 'Anguy', 9),
#  ('Rickon Stark', 'Jojen Reed', 9),
#  ('Rickon Stark', 'Meera Reed', 9),
#  ('Talisa Maegyr', 'Brynden Tully', 9),
#  ('Lothar Frey', 'Black Walder Rivers', 9),
#  ('Walder Frey', 'Lothar Frey', 9),
#  ('Thenn Warg', 'Styr', 9),
#  ('Tormund Giantsbane', 'Thenn Warg', 9),
#  ('Ygritte', 'Thenn Warg', 9),
#  ('Ellaria Sand', 'Cersei Lannister', 9),
#  ('Jaime Lannister', 'Grand Maester Pycelle', 9),
#  ('Loras Tyrell', 'Jaime Lannister', 9),
#  ('Hizdahr zo Loraq', 'Barristan Selmy', 9),
#  ('Locke', 'Jon Snow', 9),
#  ('Othell Yarwyck', 'Eddison Tollett', 9),
#  ('Melisandre', 'Eddison Tollett', 9),
#  ('Shireen Baratheon', 'Selyse Baratheon', 9),
#  ('Ellaria Sand', 'Doran Martell', 9),
#  ('The Waif', "Jaqen H'ghar", 9),
#  ('Olly', 'Bowen Marsh', 9),
#  ('Loras Tyrell', 'High Sparrow', 9),
#  ('Yezzan zo Qaggaz', 'Tyrion Lannister', 9),
#  ('Septa Unella', 'High Sparrow', 9),
#  ('Young Ned Stark', 'Three-Eyed Raven', 9),
#  ('Ramsay Snow', 'Harald Karstark', 9),
#  ('Bobono', 'Bianca', 9),
#  ('Izembaro', 'Bianca', 9),
#  ('Theon Greyjoy', 'Euron Greyjoy', 9),
#  ('Robett Glover', 'Jon Snow', 9),
#  ('Davos Seaworth', 'Alys Karstark', 9),
#  ('Yohn Royce', 'Alys Karstark', 9),
#  ('Sansa Stark', 'Maester Wolkan', 9),
#  ('Jaime Lannister', 'Dickon Tarly', 9),
#  ('Randyll Tarly', 'Jaime Lannister', 9),
#  ('Drogon', 'Bronn', 9),
#  ('Qhono', 'Jaime Lannister', 9),
#  ('Podrick Payne', 'Jorah Mormont', 9),
#  ('Jorah Mormont', 'Bran Stark', 9),
#  ('Yohn Royce', 'Jorah Mormont', 9),
#  ('Bran Stark', 'Alys Karstark', 9),
#  ('Tormund Giantsbane', 'Lord Varys', 9),
#  ('Yohn Royce', 'Samwell Tarly', 9),
#  ("Eleanor's Daughter", 'Eleanor', 9),
#  ('Catelyn Stark', 'Bran Stark', 8),
#  ('Eddard Stark', 'Bran Stark', 8),
#  ('Summer', 'Shaggydog', 8),
#  ('Jaime Lannister', 'Arya Stark', 8),
#  ('Joffrey Baratheon', 'Eddard Stark', 8),
#  ('Jon Snow', 'Cersei Lannister', 8),
#  ('Robert Baratheon', 'Cersei Lannister', 8),
#  ('Sandor Clegane', 'Eddard Stark', 8),
#  ('Ilyn Payne', 'Cersei Lannister', 8),
#  ('Renly Baratheon', 'Eddard Stark', 8),
#  ('Petyr Baelish', 'Joffrey Baratheon', 8),
#  ('Robb Stark', 'Greatjon Umber', 8),
#  ('Theon Greyjoy', 'Greatjon Umber', 8),
#  ('Shaggydog', 'Osha', 8),
#  ('Shaggydog', 'Rickon Stark', 8),
#  ('Tyrion Lannister', 'Petyr Baelish', 8),
#  ('Jeor Mormont', 'Craster', 8),
#  ('Selyse Baratheon', 'Davos Seaworth', 8),
#  ('Polliver', 'Arya Stark', 8),
#  ('Lancel Lannister', 'Joffrey Baratheon', 8),
#  ('Sandor Clegane', 'Lancel Lannister', 8),
#  ('Tyrion Lannister', 'Lancel Lannister', 8),
#  ('Tommen Baratheon', 'High Septon', 8),
#  ('Summer', 'Osha', 8),
#  ('Rast', 'Eddison Tollett', 8),
#  ('Olenna Tyrell', 'Lord Varys', 8),
#  ('Rhaegal', 'Missandei', 8),
#  ('Olenna Tyrell', 'Grand Maester Pycelle', 8),
#  ('Olenna Tyrell', 'Loras Tyrell', 8),
#  ('Tywin Lannister', 'High Septon', 8),
#  ('Oberyn Martell', 'Lord Varys', 8),
#  ('Tywin Lannister', 'Ellaria Sand', 8),
#  ('Tormund Giantsbane', 'Olly', 8),
#  ('Jorah Mormont', 'Hizdahr zo Loraq', 8),
#  ('Robin Arryn', 'Petyr Baelish', 8),
#  ('Sansa Stark', 'Robin Arryn', 8),
#  ('Olly', 'Davos Seaworth', 8),
#  ('Stannis Baratheon', 'Samwell Tarly', 8),
#  ('Leaf', 'Hodor', 8),
#  ('Three-Eyed Raven', 'Hodor', 8),
#  ('Three-Eyed Raven', 'Meera Reed', 8),
#  ('Yohn Royce', 'Robin Arryn', 8),
#  ('Kevan Lannister', 'Grand Maester Pycelle', 8),
#  ('Nymeria Sand', 'Ellaria Sand', 8),
#  ('Obara Sand', 'Ellaria Sand', 8),
#  ('Tommen Baratheon', 'High Sparrow', 8),
#  ('Theon Greyjoy', 'Podrick Payne', 8),
#  ('Wyllis', 'Bran Stark', 8),
#  ('Rickon Stark', 'Ramsay Snow', 8),
#  ('Bianca', 'Arya Stark', 8),
#  ('Bobono', 'Arya Stark', 8),
#  ('Camello', 'Bobono', 8),
#  ('Lady Crane', 'Bianca', 8),
#  ('Lady Crane', 'Bobono', 8),
#  ('Lady Crane', 'Izembaro', 8),
#  ('Robett Glover', 'Davos Seaworth', 8),
#  ('Smalljon Umber', 'Jon Snow', 8),
#  ('Tormund Giantsbane', 'Smalljon Umber', 8),
#  ('Margaery Tyrell', 'Kevan Lannister', 8),
#  ('Robett Glover', 'Lyanna Mormont', 8),
#  ('Brienne of Tarth', 'Alys Karstark', 8),
#  ('Lyanna Mormont', 'Alys Karstark', 8),
#  ('Daenerys Targaryen', 'Bronn', 8),
#  ('Jaime Lannister', 'Drogon', 8),
#  ('Daenerys Targaryen', 'Beric Dondarrion', 8),
#  ('Drogon', 'Cersei Lannister', 8),
#  ('Euron Greyjoy', 'Drogon', 8),
#  ('Missandei', 'Lyanna Mormont', 8),
#  ('Lyanna Mormont', 'Lord Varys', 8),
#  ('Tyrion Lannister', 'Lyanna Mormont', 8),
#  ('Eddison Tollett', 'Beric Dondarrion', 8),
#  ('Samwell Tarly', 'Lord Varys', 8),
#  ('Lord Varys', 'Gilly', 8),
#  ('Sansa Stark', 'Gilly', 8),
#  ('Grey Worm', 'Cersei Lannister', 8),
#  ('Grey Worm', 'Euron Greyjoy', 8),
#  ('Grey Worm', 'Gregor Clegane', 8),
#  ('Shaggydog', 'Bran Stark', 7),
#  ('Jaime Lannister', 'Catelyn Stark', 7),
#  ('Rickon Stark', 'Maester Luwin', 7),
#  ('Summer', 'Rickon Stark', 7),
#  ('Tommen Baratheon', 'Sandor Clegane', 7),
#  ('Qotho', 'Daenerys Targaryen', 7),
#  ('Qotho', 'Khal Drogo', 7),
#  ('Viserys Targaryen', 'Khal Drogo', 7),
#  ('Viserys Targaryen', 'Jorah Mormont', 7),
#  ('Khal Drogo', 'Irri', 7),
#  ('Rakharo', 'Khal Drogo', 7),
#  ('Tommen Baratheon', 'Gregor Clegane', 7),
#  ('Theon Greyjoy', 'Osha', 7),
#  ('Rakharo', 'Doreah', 7),
#  ('Maester Aemon', 'Alliser Thorne', 7),
#  ('Mirri Maz Duur', 'Daenerys Targaryen', 7),
#  ('Greatjon Umber', 'Catelyn Stark', 7),
#  ('Rodrik Cassel', 'Greatjon Umber', 7),
#  ('Robb Stark', 'Rickard Karstark', 7),
#  ('Sandor Clegane', 'Bronn', 7),
#  ('Tommen Baratheon', 'Meryn Trant', 7),
#  ('Yara Greyjoy', 'Balon Greyjoy', 7),
#  ('Qhorin Halfhand', 'Jon Snow', 7),
#  ('Maester Luwin', 'Dagmer Cleftjaw', 7),
#  ('Xaro Xhoan Daxos', 'Kovarro', 7),
#  ('Rattleshirt', 'Jon Snow', 7),
#  ('Joffrey Baratheon', 'Hallyne', 7),
#  ('Sandor Clegane', 'Anguy', 7),
#  ('Rast', 'Karl Tanner', 7),
#  ('Stannis Baratheon', 'Shireen Baratheon', 7),
#  ('Shireen Baratheon', 'Davos Seaworth', 7),
#  ('Robb Stark', 'Lothar Frey', 7),
#  ('Viserion', 'Missandei', 7),
#  ('Walder Frey', 'Edmure Tully', 7),
#  ('Walder Frey', 'Roose Bolton', 7),
#  ('Olyvar', 'Ellaria Sand', 7),
#  ('Olyvar', 'Oberyn Martell', 7),
#  ('Maester Aemon', 'Janos Slynt', 7),
#  ('Meryn Trant', 'Mace Tyrell', 7),
#  ('Bronn', 'Brienne of Tarth', 7),
#  ('Mace Tyrell', 'Gregor Clegane', 7),
#  ('Mag the Mighty', 'Dongo the Giant', 7),
#  ('Donnel Hill', 'Cooper', 7),
#  ('Grenn', 'Cooper', 7),
#  ('Grenn', 'Donnel Hill', 7),
#  ('Stannis Baratheon', 'Eddison Tollett', 7),
#  ('Stannis Baratheon', 'Olly', 7),
#  ('Gilly', 'Davos Seaworth', 7),
#  ('Ellaria Sand', 'Areo Hotah', 7),
#  ('Eddison Tollett', 'Bowen Marsh', 7),
#  ('Myrcella Baratheon', 'Areo Hotah', 7),
#  ('Nymeria Sand', 'Bronn', 7),
#  ('Obara Sand', 'Bronn', 7),
#  ('Tyene Sand', 'Bronn', 7),
#  ('Trystane Martell', 'Jaime Lannister', 7),
#  ('Tyrion Lannister', 'Hizdahr zo Loraq', 7),
#  ('Lancel Lannister', 'High Sparrow', 7),
#  ('Karsi', 'Jon Snow', 7),
#  ('Tormund Giantsbane', 'Karsi', 7),
#  ('White Walker', 'Tormund Giantsbane', 7),
#  ('Stannis Baratheon', 'Baratheon General', 7),
#  ("Loyal Night's Watchman #1", 'Davos Seaworth', 7),
#  ("Loyal Night's Watchman #1", 'Jon Snow', 7),
#  ("Loyal Night's Watchman #2", 'Davos Seaworth', 7),
#  ("Loyal Night's Watchman #2", 'Jon Snow', 7),
#  ("Loyal Night's Watchman #2", "Loyal Night's Watchman #1", 7),
#  ('Viserion', 'Tyrion Lannister', 7),
#  ('Smalljon Umber', 'Harald Karstark', 7),
#  ('Eddison Tollett', 'Brienne of Tarth', 7),
#  ('Camello', 'Bianca', 7),
#  ('Clarenzo', 'Bianca', 7),
#  ('Clarenzo', 'Bobono', 7),
#  ('Izembaro', 'Arya Stark', 7),
#  ('Izembaro', 'Camello', 7),
#  ('Izembaro', 'Clarenzo', 7),
#  ('Lady Crane', 'Camello', 7),
#  ('Lady Crane', 'Clarenzo', 7),
#  ('Margaery Tyrell Mummer', 'Bobono', 7),
#  ('Margaery Tyrell Mummer', 'Camello', 7),
#  ('Euron Greyjoy', 'Aeron Greyjoy', 7),
#  ('Wun Wun', 'Davos Seaworth', 7),
#  ('Petyr Baelish', 'Jon Snow', 7),
#  ('Loras Tyrell', 'Kevan Lannister', 7),
#  ('Jon Snow', 'Alys Karstark', 7),
#  ('Podrick Payne', 'Lyanna Mormont', 7),
#  ('Rhaegal', 'Lord Varys', 7),
#  ('Drogon', 'Davos Seaworth', 7),
#  ('Qhono', 'Drogon', 7),
#  ('Sandor Clegane', 'Drogon', 7),
#  ('Tormund Giantsbane', 'Drogon', 7),
#  ('Davos Seaworth', 'Bronn', 7),
#  ('Davos Seaworth', 'Cersei Lannister', 7),
#  ('Gregor Clegane', 'Brienne of Tarth', 7),
#  ('Gregor Clegane', 'Davos Seaworth', 7),
#  ('Jon Snow', 'Gregor Clegane', 7),
#  ('Jorah Mormont', 'Cersei Lannister', 7),
#  ('Jorah Mormont', 'Gregor Clegane', 7),
#  ('Qhono', 'Cersei Lannister', 7),
#  ('Qhono', 'Gregor Clegane', 7),
#  ('Qyburn', 'Davos Seaworth', 7),
#  ('Qyburn', 'Jon Snow', 7),
#  ('Qyburn', 'Jorah Mormont', 7),
#  ('Qyburn', 'Qhono', 7),
#  ('Sandor Clegane', 'Qyburn', 7),
#  ('Theon Greyjoy', 'Gregor Clegane', 7),
#  ('Theon Greyjoy', 'Qyburn', 7),
#  ('Gregor Clegane', 'Drogon', 7),
#  ('Sansa Stark', 'Jorah Mormont', 7),
#  ('Tyrion Lannister', 'Alys Karstark', 7),
#  ('Missandei', 'Arya Stark', 7),
#  ('Samwell Tarly', 'Missandei', 7),
#  ('Missandei', 'Gilly', 7),
#  ('Tyrion Lannister', 'Gilly', 7),
#  ('Qyburn', 'Grey Worm', 7),
#  ('Jon Snow', 'Eddard Stark', 6),
#  ('Robb Stark', 'Jon Snow', 6),
#  ('Rodrik Cassel', 'Bran Stark', 6),
#  ('Rodrik Cassel', 'Eddard Stark', 6),
#  ('Theon Greyjoy', 'Eddard Stark', 6),
#  ('Robb Stark', 'Grey Wind', 6),
#  ('Joffrey Baratheon', 'Arya Stark', 6),
#  ('Robert Baratheon', 'Joffrey Baratheon', 6),
#  ('Sandor Clegane', 'Bran Stark', 6),
#  ('Theon Greyjoy', 'Hodor', 6),
#  ('Jon Snow', 'Benjen Stark', 6),
#  ('Tyrion Lannister', 'Benjen Stark', 6),
#  ('Drogon', 'Doreah', 6),
#  ('Renly Baratheon', 'Grand Maester Pycelle', 6),
#  ('Lord Varys', 'Janos Slynt', 6),
#  ('Petyr Baelish', 'Janos Slynt', 6),
#  ('Grenn', 'Ghost', 6),
#  ('Tyrion Lannister', 'Catelyn Stark', 6),
#  ('Eddard Stark', 'Barristan Selmy', 6),
#  ('Renly Baratheon', 'Loras Tyrell', 6),
#  ('Tyrion Lannister', 'Robin Arryn', 6),
#  ('Othell Yarwyck', 'Maester Aemon', 6),
#  ('Mirri Maz Duur', 'Jorah Mormont', 6),
#  ('Rickard Karstark', 'Catelyn Stark', 6),
#  ('Lommy Greenhands', 'Arya Stark', 6),
#  ('Lommy Greenhands', 'Gendry', 6),
#  ('Lommy Greenhands', 'Hot Pie', 6),
#  ('Yoren', 'Gendry', 6),
#  ('Myrcella Baratheon', 'Bronn', 6),
#  ('Renly Baratheon', 'Brienne of Tarth', 6),
#  ('Tywin Lannister', 'Gregor Clegane', 6),
#  ('Ygritte', 'Rattleshirt', 6),
#  ('Kevan Lannister', 'Gregor Clegane', 6),
#  ('Tyrion Lannister', 'Mandon Moore', 6),
#  ('Podrick Payne', 'Hallyne', 6),
#  ('White Walker', 'Samwell Tarly', 6),
#  ('Karl Tanner', 'Jeor Mormont', 6),
#  ('Samwell Tarly', 'Karl Tanner', 6),
#  ('Podrick Payne', 'Petyr Baelish', 6),
#  ('Beric Dondarrion', 'Anguy', 6),
#  ('Melisandre', 'Gendry', 6),
#  ('Edmure Tully', 'Black Walder Rivers', 6),
#  ('Lothar Frey', 'Catelyn Stark', 6),
#  ('Razdal mo Eraz', 'Grey Worm', 6),
#  ('Razdal mo Eraz', 'Missandei', 6),
#  ('Theon Greyjoy', 'Myranda', 6),
#  ('High Septon', 'Grand Maester Pycelle', 6),
#  ('Robb Stark', 'Joyeuse Erenford', 6),
#  ('Talisa Maegyr', 'Lothar Frey', 6),
#  ('Walder Frey', 'Black Walder Rivers', 6),
#  ('Roose Bolton', 'Edmure Tully', 6),
#  ('Roslin Frey', 'Catelyn Stark', 6),
#  ('Roslin Frey', 'Edmure Tully', 6),
#  ('Roslin Frey', 'Roose Bolton', 6),
#  ('Othell Yarwyck', 'Janos Slynt', 6),
#  ('Walda Bolton', 'Ramsay Snow', 6),
#  ('Theon Greyjoy', 'Roose Bolton', 6),
#  ('White Walker', 'Bran Stark', 6),
#  ('Mace Tyrell', 'High Septon', 6),
#  ('Tommen Baratheon', 'Lord Varys', 6),
#  ('Grand Maester Pycelle', 'Ellaria Sand', 6),
#  ('Mace Tyrell', 'Ellaria Sand', 6),
#  ('Tommen Baratheon', 'Oberyn Martell', 6),
#  ('Musician #2', 'Musician #1', 6),
#  ('Musician #3', 'Musician #1', 6),
#  ('Musician #3', 'Musician #2', 6),
#  ('Oznak zo Pahl', 'Daenerys Targaryen', 6),
#  ('Oznak zo Pahl', 'Daario Naharis', 6),
#  ('Locke', 'Grenn', 6),
#  ('Olly', 'Grenn', 6),
#  ('Hizdahr zo Loraq', 'Grey Worm', 6),
#  ('Tormund Giantsbane', 'Gilly', 6),
#  ('Davos Seaworth', 'Alliser Thorne', 6),
#  ('Myrcella Baratheon', 'Doran Martell', 6),
#  ('Trystane Martell', 'Doran Martell', 6),
#  ('Qyburn', 'Mace Tyrell', 6),
#  ('Sansa Stark', 'Myranda', 6),
#  ('Trystane Martell', 'Areo Hotah', 6),
#  ('Jaime Lannister', 'Areo Hotah', 6),
#  ('Tyene Sand', 'Areo Hotah', 6),
#  ('Olenna Tyrell', 'High Sparrow', 6),
#  ('Tormund Giantsbane', 'The Night King', 6),
#  ('Daenerys Targaryen', 'Akho', 6),
#  ('Qhono', 'Akho', 6),
#  ('Jaime Lannister', 'High Sparrow', 6),
#  ('High Priestess', 'Daenerys Targaryen', 6),
#  ('Ornela', 'Daenerys Targaryen', 6),
#  ('Ornela', 'High Priestess', 6),
#  ('Qyburn', 'Little Bird #3', 6),
#  ('Sansa Stark', 'Eddison Tollett', 6),
#  ('Yezzan zo Qaggaz', 'Grey Worm', 6),
#  ('Yezzan zo Qaggaz', 'Missandei', 6),
#  ('Camello', 'Arya Stark', 6),
#  ('Clarenzo', 'Arya Stark', 6),
#  ('Margaery Tyrell Mummer', 'Bianca', 6),
#  ('Margaery Tyrell Mummer', 'Izembaro', 6),
#  ('Margaery Tyrell Mummer', 'Lady Crane', 6),
#  ('The Night King', 'Leaf', 6),
#  ('Sandor Clegane', 'Brother Ray', 6),
#  ('Lothar Frey', 'Jaime Lannister', 6),
#  ('Smalljon Umber', 'Davos Seaworth', 6),
#  ('Tormund Giantsbane', 'Petyr Baelish', 6),
#  ('Kevan Lannister', 'High Sparrow', 6),
#  ('Lancel Lannister', 'Arthur', 6),
#  ('Robett Glover', 'Petyr Baelish', 6),
#  ('Robett Glover', 'Brienne of Tarth', 6),
#  ('Sansa Stark', 'Alys Karstark', 6),
#  ('Ned Umber', 'Jon Snow', 6),
#  ('Sansa Stark', 'Ned Umber', 6),
#  ('Samwell Tarly', 'Archmaester Ebrose', 6),
#  ('Rhaegal', 'Davos Seaworth', 6),
#  ('Dickon Tarly', 'Bronn', 6),
#  ('Randyll Tarly', 'Bronn', 6),
#  ('Drogon', 'Beric Dondarrion', 6),
#  ('Tormund Giantsbane', 'Rhaegal', 6),
#  ('Qyburn', 'Drogon', 6),
#  ('Lord Varys', 'Alys Karstark', 6),
#  ('Teela', 'Gilly', 6),
#  ('Tormund Giantsbane', 'Arya Stark', 6),
#  ('Tormund Giantsbane', 'Bran Stark', 6),
#  ('Tormund Giantsbane', 'Missandei', 6),
#  ('Jorah Mormont', 'Ghost', 6),
#  ('Teela', 'Lord Varys', 6),
#  ('Teela', 'Sansa Stark', 6),
#  ('Tyrion Lannister', 'Teela', 6),
#  ('Gendry', 'Bran Stark', 6),
#  ('Sansa Stark', 'Gendry', 6),
#  ('Eleanor', 'Arya Stark', 6),
#  ("Eleanor's Daughter", 'Arya Stark', 6),
#  ('Waymar Royce', 'Gared', 5),
#  ('Robb Stark', 'Eddard Stark', 5),
#  ('Septa Mordane', 'Eddard Stark', 5),
#  ('Theon Greyjoy', 'Arya Stark', 5),
#  ('Ghost', 'Bran Stark', 5),
#  ('Maester Luwin', 'Catelyn Stark', 5),
#  ('Cersei Lannister', 'Arya Stark', 5),
#  ('Jory Cassel', 'Arya Stark', 5),
#  ('Myrcella Baratheon', 'Cersei Lannister', 5),
#  ('Sandor Clegane', 'Myrcella Baratheon', 5),
#  ('Sansa Stark', 'Myrcella Baratheon', 5),
#  ('Sansa Stark', 'Robert Baratheon', 5),
#  ('Khal Drogo', 'Drogon', 5),
#  ('Qotho', 'Jorah Mormont', 5),
#  ('Rhaegal', 'Khal Drogo', 5),
#  ('Viserion', 'Khal Drogo', 5),
#  ('Khal Drogo', 'Doreah', 5),
#  ('Viserys Targaryen', 'Doreah', 5),
#  ('Viserys Targaryen', 'Irri', 5),
#  ('Rast', 'Ghost', 5),
#  ('Tyrion Lannister', 'Ghost', 5),
#  ('Royal Steward', 'Eddard Stark', 5),
#  ('Renly Baratheon', 'Lord Varys', 5),
#  ('Robert Baratheon', 'Barristan Selmy', 5),
#  ('Syrio Forel', 'Arya Stark', 5),
#  ('Gregor Clegane', 'Arya Stark', 5),
#  ('Joffrey Baratheon', 'Barristan Selmy', 5),
#  ('Renly Baratheon', 'Barristan Selmy', 5),
#  ('Robert Baratheon', 'Renly Baratheon', 5),
#  ('Sandor Clegane', 'Petyr Baelish', 5),
#  ('Catelyn Stark', 'Bronn', 5),
#  ('Rodrik Cassel', 'Bronn', 5),
#  ('Tyrion Lannister', 'Rodrik Cassel', 5),
#  ('Petyr Baelish', 'Loras Tyrell', 5),
#  ('Robin Arryn', 'Lysa Arryn', 5),
#  ('Ros', 'Petyr Baelish', 5),
#  ('Rakharo', 'Mirri Maz Duur', 5),
#  ('Stannis Baratheon', 'Matthos Seaworth', 5),
#  ('Margaery Tyrell', 'Brienne of Tarth', 5),
#  ('Arya Stark', 'Amory Lorch', 5),
#  ('Petyr Baelish', 'Margaery Tyrell', 5),
#  ('Pyat Pree', 'Daenerys Targaryen', 5),
#  ('Dagmer Cleftjaw', 'Black Lorren', 5),
#  ('Theon Greyjoy', 'Black Lorren', 5),
#  ('Tyrion Lannister', 'High Septon', 5),
#  ('Shaggydog', 'Hodor', 5),
#  ('Shae', 'Handmaid', 5),
#  ('Lord Varys', 'Bronn', 5),
#  ('Podrick Payne', 'Mandon Moore', 5),
#  ('Tommen Baratheon', 'Shae', 5),
#  ('Joffrey Baratheon', 'Captain of the Archers', 5),
#  ('Kraznys mo Nakloz', 'Daenerys Targaryen', 5),
#  ('Kraznys mo Nakloz', 'Jorah Mormont', 5),
#  ('Missandei', 'Kraznys mo Nakloz', 5),
#  ('Karl Tanner', 'Craster', 5),
#  ('Olyvar', 'Loras Tyrell', 5),
#  ('Melisandre', 'Arya Stark', 5),
#  ('Melisandre', 'Beric Dondarrion', 5),
#  ('Talisa Maegyr', 'Joyeuse Erenford', 5),
#  ('Roslin Frey', 'Robb Stark', 5),
#  ('Talisa Maegyr', 'Roslin Frey', 5),
#  ('Walder Frey', 'Roslin Frey', 5),
#  ('Todder', 'Jon Snow', 5),
#  ('Drogon', 'Daario Naharis', 5),
#  ('Meryn Trant', 'Jaime Lannister', 5),
#  ('Walda Bolton', 'Roose Bolton', 5),
#  ('Jaime Lannister', 'High Septon', 5),
#  ('Lord Varys', 'Ellaria Sand', 5),
#  ('Olenna Tyrell', 'Ellaria Sand', 5),
#  ('Meryn Trant', 'Margaery Tyrell', 5),
#  ('Olly', 'Maester Aemon', 5),
#  ('Pypar', 'Janos Slynt', 5),
#  ('Pypar', 'Eddison Tollett', 5),
#  ('Oznak zo Pahl', 'Barristan Selmy', 5),
#  ('Oznak zo Pahl', 'Missandei', 5),
#  ('Mossador', 'Grey Worm', 5),
#  ('Sansa Stark', 'Lysa Arryn', 5),
#  ('Sissy', 'Jon Snow', 5),
#  ...]

# %% [markdown]
# #### Interesting View
#
# - Create a view of the information that you think would be interesting to fans.
#
#
# - Explain what you view is producing.
#
# <u>Answer:</u>

# %% [markdown]
# ## Task 5
#
# ### Programming

# %% [markdown]
# #### Data Processing and Cleansing
#
#
# - The ```scene``` information in ```episodes.json``` complements and extend some of the information about character interactions and relationships. An example is:
#
# ```
#             {
#                "sceneStart":"0:50:24",
#                "sceneEnd":"0:55:54",
#                "location":"The Crownlands",
#                "subLocation":"King's Landing",
#                "characters":[
#                   {
#                      "name":"Arya Stark",
#                      "weapon":[
#                         {"action":"has", "name":"Needle"}
#                      ]
#                   },
#                   {
#                      "name":"Eddard Stark",
#                      "title":"Hand",
#                      "alive":false,
#                      "mannerOfDeath":"Decapitation",
#                      "killedBy":[
#                         "Ilyn Payne"
#                      ]
#                   },
#                   {"name":"Yoren"},
#                   {"name":"Sansa Stark"},
#                   {"name":"Petyr Baelish"},
#                   {"name":"Cersei Lannister"},
#                   {"name":"Joffrey Baratheon", "title":"King"},
#                   {"name":"Grand Maester Pycelle"},
#                   {"name":"Lord Varys"},
#                   {"name":"Sandor Clegane"},
#                   {
#                      "name":"Ilyn Payne",
#                      "weapon":[
#                         {"action":"has", "name":"Ice"}
#                      ]
#                   }
#                ]
#             }
#          ]
# ```
#
#
# - A little data processing determines that the top-level elements of a ```character``` in a scene are:
#
# ```Top level keys in characters in scenes are:
# 	 sex
# 	 name
# 	 weapon
# 	 born
# 	 married
# 	 killedBy
# 	 mannerOfDeath
# 	 title
# 	 alive
# ```

# %% [markdown]
# - Your data processing and cleanse tasks is to create a table of the form:
#     - ```seasonNum```
#     - ```episodeNum```
#     - ```sceneNo```
#     - ```character_id_1```
#     - ```action```
#     - ```character_id_2```
#
#
# - You can get access to information that maps ```characterName``` to ```character_id``` using the following code.

# %%
import pymysql 

cloud_conn = pymysql.connect(
    host="columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
    user="gotuser",
    password="gotusergotuser",
    db="W4111GoTSolutionClean",
    cursorclass=pymysql.cursors.DictCursor
)

# %%
def get_character_info(c_name, conn):
    sql = "select * from characters where characterName=%s"
    cur = conn.cursor()
    res = cur.execute(sql, (c_name))
    res = cur.fetchall()
    return res

# %%
get_character_info("Sansa Stark", cloud_conn)
# Out:
# [{'id': 300,
#   'characterName': 'Sansa Stark',
#   'characterLink': '/character/ch0158137/',
#   'actorName': 'Sophie Turner',
#   'actorLink': '/name/nm3849842/',
#   'character_id': 'CH_300',
#   'royal': 1,
#   'characterImageThumb': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg',
#   'characterImageFull': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg',
#   'nickname': None,
#   'kingsguard': 0}]

# %% [markdown]
# #### Answer

# %% [markdown]
# <u>Table Definition</u>

# %%
import os
import pymysql
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = pd.read_json(os.getcwd() + '/Data/json/episodes.json')

# %%
killed = []
married = []
sex = []
for m in df['episodes']:
    for sceNum in range(len(m['scenes'])):
        sceneStart = m['scenes'][sceNum]['sceneStart']
        sceneEnd = m['scenes'][sceNum]['sceneEnd']
        
        for char in m['scenes'][sceNum]['characters']:
            if char.get('killedBy'):
                for i in range(len(char['killedBy'])):
                        killed.append((sceneStart, sceneEnd, sceNum, m['seasonNum'], m['episodeNum'], char['name'], char['killedBy']))
            if char.get('married'):
                married.append((sceneStart, sceneEnd, sceNum, m['seasonNum'], m['episodeNum'], char['name'], char['married']['to']))

            if char.get('sex'):
                for i in range(len(char['sex']['with'])):
                    sex.append((sceneStart, sceneEnd, sceNum, m['seasonNum'], m['episodeNum'], char['name'], char['sex']['with']))

# %%
killDF = pd.DataFrame(killed, columns=['sceneStart', 'sceneEnd', 'sceneNo', 'seasonNum', 'episodeNum', 'name', 'killedBy'])
killDF['killedBy'] = pd.DataFrame(killDF['killedBy'].values.tolist())
killDF.head()
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum              name  \
# 0    0:05:58  0:06:21        9          1           1      Waymar Royce
# 1    0:06:49  0:07:45       12          1           1             Gared
# 2    0:12:38  0:15:41       14          1           1              Will
# 3    0:18:44  0:20:45       16          1           1         Jon Arryn
# 4    0:29:16  0:32:28       12          1           2  Catspaw Assassin
#
#        killedBy
# 0  White Walker
# 1  White Walker
# 2  Eddard Stark
# 3    Lysa Arryn
# 4        Summer

# %%
marriedDF = pd.DataFrame(married, columns=['sceneStart', 'sceneEnd', 'sceneNo', 'seasonNum', 'episodeNum', 'name', 'married'])
marriedDF.head()
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum                name  \
# 0    0:50:29  0:56:05       32          1           1          Khal Drogo
# 1    0:50:29  0:56:05       32          1           1  Daenerys Targaryen
# 2    0:09:16  0:13:24        6          2           3     Renly Baratheon
# 3    0:09:16  0:13:24        6          2           3     Margaery Tyrell
# 4    0:33:32  0:34:23       16          2          10          Robb Stark
#
#               married
# 0  Daenerys Targaryen
# 1          Khal Drogo
# 2     Margaery Tyrell
# 3     Renly Baratheon
# 4       Talisa Maegyr

# %%
sexDF = pd.DataFrame(sex, columns=['sceneStart', 'sceneEnd', 'sceneNo', 'seasonNum', 'episodeNum', 'name', 'sex'])
sexDF['sex'] = pd.DataFrame(sexDF['sex'].values.tolist())
sexDF.head()
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum                name  \
# 0    0:30:47  0:32:57       22          1           1    Tyrion Lannister
# 1    0:30:47  0:32:57       22          1           1                 Ros
# 2    0:56:05  0:57:48       33          1           1          Khal Drogo
# 3    0:56:05  0:57:48       33          1           1  Daenerys Targaryen
# 4    0:59:06  1:00:57       35          1           1     Jaime Lannister
#
#                   sex
# 0                 Ros
# 1    Tyrion Lannister
# 2  Daenerys Targaryen
# 3          Khal Drogo
# 4    Cersei Lannister

# %%
final = pd.concat([killDF, marriedDF, sexDF], axis=0)
final['action'] = final[['killedBy', 'married', 'sex']].apply(lambda s: s.dropna().index[0], axis=1)
final['target'] = final[['killedBy', 'married', 'sex']].apply(lambda s: s.dropna().values[0], axis=1)
final.drop(['killedBy', 'married', 'sex'], axis=1, inplace=True, errors='ignore')
final = final[['sceneStart', 'sceneEnd', 'sceneNo', 'seasonNum', 'episodeNum', 'name', 'action', 'target']]

# %%
final.head()
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum              name  \
# 0    0:05:58  0:06:21        9          1           1      Waymar Royce
# 1    0:06:49  0:07:45       12          1           1             Gared
# 2    0:12:38  0:15:41       14          1           1              Will
# 3    0:18:44  0:20:45       16          1           1         Jon Arryn
# 4    0:29:16  0:32:28       12          1           2  Catspaw Assassin
#
#      action        target
# 0  killedBy  White Walker
# 1  killedBy  White Walker
# 2  killedBy  Eddard Stark
# 3  killedBy    Lysa Arryn
# 4  killedBy        Summer

# %%
final.shape
# Out:
# (408, 8)

# %%
final.loc[final.duplicated()]
# Out:
#     sceneStart sceneEnd  sceneNo  seasonNum  episodeNum  \
# 80     0:49:38  0:50:43       80          4           2
# 86     0:44:43  0:45:22       39          4           5
# 108    0:47:49  0:48:44       84          4           9
# 109    0:47:49  0:48:44       84          4           9
# 142    1:01:29  1:02:01       63          5          10
# 143    1:01:29  1:02:01       63          5          10
# 144    1:01:29  1:02:01       63          5          10
# 158    0:17:49  0:19:50        6          6           3
# 195    0:16:44  0:17:00       29          6          10
# 196    0:16:44  0:17:00       29          6          10
# 197    0:16:44  0:17:00       29          6          10
# 198    0:16:44  0:17:00       29          6          10
# 199    0:16:44  0:17:00       29          6          10
# 53     0:38:11  0:39:25       31          3           3
# 54     0:38:11  0:39:25       31          3           3
# 65     0:35:01  0:38:52       33          3           7
# 73     0:31:58  0:34:00       32          4           3
# 74     0:31:58  0:34:00       32          4           3
# 75     0:31:58  0:34:00       32          4           3
# 77     0:31:58  0:34:00       32          4           3
# 78     0:31:58  0:34:00       32          4           3
# 79     0:31:58  0:34:00       32          4           3
# 81     0:31:58  0:34:00       32          4           3
# 82     0:31:58  0:34:00       32          4           3
# 83     0:31:58  0:34:00       32          4           3
# 85     0:31:58  0:34:00       32          4           3
# 86     0:31:58  0:34:00       32          4           3
# 87     0:31:58  0:34:00       32          4           3
# 89     0:31:58  0:34:00       32          4           3
# 90     0:31:58  0:34:00       32          4           3
# 91     0:31:58  0:34:00       32          4           3
#
#                       name    action         target
# 80       Joffrey Baratheon  killedBy  Olenna Tyrell
# 86                   Locke  killedBy          Hodor
# 108         Mag the Mighty  killedBy          Grenn
# 109         Mag the Mighty  killedBy          Grenn
# 142               Jon Snow  killedBy           Olly
# 143               Jon Snow  killedBy           Olly
# 144               Jon Snow  killedBy           Olly
# 158           Arthur Dayne  killedBy   Howland Reed
# 195  Grand Maester Pycelle  killedBy        Frances
# 196  Grand Maester Pycelle  killedBy        Frances
# 197  Grand Maester Pycelle  killedBy        Frances
# 198  Grand Maester Pycelle  killedBy        Frances
# 199  Grand Maester Pycelle  killedBy        Frances
# 53           Podrick Payne       sex          Genna
# 54           Podrick Payne       sex          Genna
# 65           Theon Greyjoy       sex        Myranda
# 73            Ellaria Sand       sex         Olyvar
# 74            Ellaria Sand       sex         Olyvar
# 75            Ellaria Sand       sex         Olyvar
# 77                  Olyvar       sex   Ellaria Sand
# 78                  Olyvar       sex   Ellaria Sand
# 79                  Olyvar       sex   Ellaria Sand
# 81                   Marei       sex   Ellaria Sand
# 82                   Marei       sex   Ellaria Sand
# 83                   Marei       sex   Ellaria Sand
# 85    King's Landing Whore       sex   Ellaria Sand
# 86    King's Landing Whore       sex   Ellaria Sand
# 87    King's Landing Whore       sex   Ellaria Sand
# 89          Oberyn Martell       sex   Ellaria Sand
# 90          Oberyn Martell       sex   Ellaria Sand
# 91          Oberyn Martell       sex   Ellaria Sand

# %%
final = final.loc[~final.duplicated()].reset_index(drop=True)

# %%
final.shape
# Out:
# (377, 8)

# %%
from sqlalchemy import create_engine
conn = create_engine('mysql+pymysql://root:rv8855741@localhost/W4111GoTSolutionClean')

# %%
characters = pd.read_sql('SELECT * FROM characters', conn)

finalColumns = final.columns.values.tolist()
final = pd.merge(final, characters, how='left', left_on='name', right_on='characterName')\
        .rename(columns={'character_id': 'characerter_1_id'})
final = pd.merge(final, characters, how='left', left_on='target', right_on='characterName')\
        .rename(columns={'character_id': 'characerter_2_id'})
final = final[finalColumns + ['characerter_1_id', 'characerter_2_id']]
final.head(3)
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum          name    action  \
# 0    0:05:58  0:06:21        9          1           1  Waymar Royce  killedBy
# 1    0:05:58  0:06:21        9          1           1  Waymar Royce  killedBy
# 2    0:05:58  0:06:21        9          1           1  Waymar Royce  killedBy
#
#          target characerter_1_id characerter_2_id
# 0  White Walker           CH_360           CH_362
# 1  White Walker           CH_360           CH_363
# 2  White Walker           CH_360           CH_364

# %%
final.tail(3)
# Out:
#     sceneStart sceneEnd  sceneNo  seasonNum  episodeNum              name  \
# 395    0:43:55  0:45:39       55          8           2            Gendry
# 396    0:25:26  0:28:29       45          8           4   Jaime Lannister
# 397    0:25:26  0:28:29       45          8           4  Brienne of Tarth
#
#     action            target characerter_1_id characerter_2_id
# 395    sex        Arya Stark            CH_70            CH_15
# 396    sex  Brienne of Tarth           CH_113            CH_31
# 397    sex   Jaime Lannister            CH_31           CH_113

# %%
final = final.iloc[ final[finalColumns].drop_duplicates().index ]
final.shape
# Out:
# (377, 10)

# %%
final.head()
# Out:
#   sceneStart sceneEnd  sceneNo  seasonNum  episodeNum              name  \
# 0    0:05:58  0:06:21        9          1           1      Waymar Royce
# 3    0:06:49  0:07:45       12          1           1             Gared
# 6    0:12:38  0:15:41       14          1           1              Will
# 7    0:18:44  0:20:45       16          1           1         Jon Arryn
# 8    0:29:16  0:32:28       12          1           2  Catspaw Assassin
#
#      action        target characerter_1_id characerter_2_id
# 0  killedBy  White Walker           CH_360           CH_362
# 3  killedBy  White Walker            CH_68           CH_362
# 6  killedBy  Eddard Stark           CH_368            CH_59
# 7  killedBy    Lysa Arryn           CH_122           CH_184
# 8  killedBy        Summer            CH_37           CH_326

# %%
final.tail()
# Out:
#     sceneStart sceneEnd  sceneNo  seasonNum  episodeNum              name  \
# 393    0:26:12  0:27:52       43          8           1     Euron Greyjoy
# 394    0:43:55  0:45:39       55          8           2        Arya Stark
# 395    0:43:55  0:45:39       55          8           2            Gendry
# 396    0:25:26  0:28:29       45          8           4   Jaime Lannister
# 397    0:25:26  0:28:29       45          8           4  Brienne of Tarth
#
#     action            target characerter_1_id characerter_2_id
# 393    sex  Cersei Lannister            CH_65            CH_38
# 394    sex            Gendry            CH_15            CH_70
# 395    sex        Arya Stark            CH_70            CH_15
# 396    sex  Brienne of Tarth           CH_113            CH_31
# 397    sex   Jaime Lannister            CH_31           CH_113

# %%
final.to_sql('events', con=conn, index=False)

# %% [markdown]
# <u>Sample Query</u>

# %%
# %sql SELECT * FROM events LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('0:05:58', '0:06:21', 9, 1, 1, 'Waymar Royce', 'killedBy', 'White Walker', 'CH_360', 'CH_362'),
#  ('0:06:49', '0:07:45', 12, 1, 1, 'Gared', 'killedBy', 'White Walker', 'CH_68', 'CH_362'),
#  ('0:12:38', '0:15:41', 14, 1, 1, 'Will', 'killedBy', 'Eddard Stark', 'CH_368', 'CH_59'),
#  ('0:18:44', '0:20:45', 16, 1, 1, 'Jon Arryn', 'killedBy', 'Lysa Arryn', 'CH_122', 'CH_184'),
#  ('0:29:16', '0:32:28', 12, 1, 2, 'Catspaw Assassin', 'killedBy', 'Summer', 'CH_37', 'CH_326')]

# %% [markdown]
# <u>Python Code</u>

# %% [markdown]
# ### Data Access Abstraction
#
# - A common API and abstraction for manipulating different database types and schema simplifies the development of web applications and other applications. There are many abstractions.
#
# | <img src="./Lecture_4_ER_SQL_Relational_GoT_9.jpg"> |
# | :---: |
# | __Data Access Objects__ |
#
# - The second programming tasks is to implement our own abstraction. This is RDBDataTable, which implements an abstraction we will use in subsequent homework assignments, and which we will use to enable our web application.
#
#
# - You can find the implementation template in the ```src``` directory of the project template.
#
#
# - For HW 1, Part C, you can copy your implementation code into this notebook and test again the cloud databases.
#
#
# - __I strongly suggest that you develop and test in PyCharm, and then copy your code into the notebook. The cells below just show you where to place your code. You should copy your code over from PyCharm.__

# %% [markdown]
# #### Implementation
#
# - ```BaseDataTable``` defines the common abstraction we will use. You do not need to do anything to this class.

# %%
# Import package to enable defining abstract classes in Python.
# Do not worry about understanding abstract base classes. This is just a class that defines
# some methods that subclasses must implement.
from abc import ABC, abstractmethod


class DataTableException(Exception):
    """
    A simple class that maps underlying implementation exceptions to generic exceptions.
    """

    invalid_method = 1001

    # General
    def __init__(self, code, message):
        self.code = code
        self.message = message

    def __str__(self):
        result = (
            type(self), {"code": self.code, "message": self.message}
        )
        result = str(result)
        return result


class BaseDataTable(ABC):
    """
    The implementation classes (XXXDataTable) for CSV database, relational, etc. will extend the
    base class and implement the abstract methods.
    """

    def __init__(self, entity_type_name, connect_info, key_columns=None, context=None):
        """

        :param entity_type_name: Name of the logcal entity type. This maps to various abstractions in
            underlying stores, e.g. file names, RDB tables, Neo4j Labels, ...
        :param connect_info: Dictionary of parameters necessary to connect to the data. See examples in subclasses.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            A primary key is a set of columns whose values are unique and uniquely identify a row. For Appearances,
            the columns are ['playerID', 'teamID', 'yearID']
        :param contex: Holds context and environment information.
        """
        self._table_name = entity_type_name
        self._connect_info = connect_info
        self._key_columns = key_columns
        self._context = context

    @abstractmethod
    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record. For example,
            for Appearances this could be ['willite01', 'BOS', '1960']
        :param field_list: A subset of the fields of the record to return. The CSV file or RDB table may have many
            additional columns, but the caller only requests this subset.
        :return: None, or a dictionary containing the columns/values for the row.
        """
        pass

    @abstractmethod
    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}. The function will return
            a derived table containing the rows that match the template.
        :param field_list: A list of requested fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A derived table containing the computed rows.
        """
        pass

    @abstractmethod
    def insert(self, new_entity, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records. Raises an exception if this
            creates a duplicate primary key.
        :return: None
        """
        pass

    @abstractmethod
    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def delete_by_key(self, key_fields, Context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def query(self, query_statement, args, context=None):
        """
        Passed through/executes a raw query in the native implementation language of the backend.
        :param query_statement: Query statement as a string.
        :param args: Args to insert into query if it is a template
        :param context:
        :return: A JSON object containing the result of the operation.
        """
        pass

    @abstractmethod
    def load(self, rows=None):
        """
        Loads data into the data table.
        :param rows:
        :return: Number of rows loaded.
        """

    @abstractmethod
    def save(self, context):
        """
        Writes any cached data to a backing store.
        :param context:
        :return:
        """

# %% [markdown]
# __RDBDataTable__
#
#
# - You only need to implement the following methods:
#     - ```__init__```
#     - ```__str__```
#     - ```find_by_template``` You only need to implement the parameters
#         - ```template```
#         - ```field_list```
#     - ```find_by_primary_key``` You only need to implement the parameters
#         - ```key_fields```
#         - ```field_list```
#
#
# - The logical behavior of the ```find_by_template``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.scenes_characters,```
#     - The call<br>
# ```
#     characters_tbl.find_by_template(
#             template={
#                 'seasonNum': 1,
#                 'episodeNum': 2
#                 },
#             field_list = ['seasonNum', 'episodeNum', 'sceneNo', 'character_id']
#             )
# ```
#     - Is equivalent to
# ```
#     select seasonNum, episodeNum, sceneNo, character_id
#         from GoTSolutionClean.scenes_characters
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - And returns the same dictionary.

# %% [markdown]
# - The logical behavior of the ```find_by_primary_key``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.episodes,```
#     - The primary key columns are ```seasonNum, episodeNum.```
#     - The invocation would be ```find_by_primary_key([1,3],field_list=['seasonNum','episodeNum','title'])```
#     - This would get converted into
# ```
# select seasonNum, episodeNum, title
#         from W4111GoTSolutionClean.episodes
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - Your class implementation MUST run a database query to determine the primary key columns and their order to form the ```where``` clause.
#     - The result is a single dictionary containing the query result.
#
#
# - We will provide tests.

# %%
from src.data_tables.BaseDataTable import BaseDataTable, DataTableException

import pandas as pd
import pymysql

import logging

logger = logging.getLogger()


class RDBDataTable(BaseDataTable):
    """
    RDBDataTable is relation DB implementation of the BaseDataTable.
    """

    # Default connection information in case the code does not pass an object
    # specific connection on object creation.
    _default_connect_info = {
        'host': "columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        'user': "gotuser",
        'password': "gotusergotuser",
        'db': "W4111GoTSolutionClean",
        'cursorclass': pymysql.cursors.DictCursor
    }
    # 'host': 'localhost',
    # 'user': 'root',
    # 'password': 'rv8855741',
    # 'db': 'W4111GoTSolutionClean',
    # 'port': 3306

    _default_cnx = None

    def _get_cnx(self):

        if self._cnx is None:
            if self._connect_info is None:
                c_info = RDBDataTable._default_connect_info
            else:
                c_info = self._connect_info

            self._cnx = pymysql.connect(
                host=c_info['host'],
                user=c_info['user'],
                password=c_info['password'],
                db=c_info['db'],
                charset='utf8mb4',
                cursorclass=pymysql.cursors.DictCursor)

        return self._cnx

    def __init__(self, table_name, key_columns=None, connect_info=None):
        """

        :param table_name: The name of the RDB table.
        :param connect_info: Dictionary of parameters necessary to connect to the data.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            This is for compatibility with other types of data table. Any value other than None is an error.
        """

        # If there is not explicit connect information, use the defaults.
        self._cnx = None
        self._connect_info = None

        if key_columns is not None:
            raise ValueError("This is an RDB Data Table. We figure out the keys by querying the DB.")

        ####### Your Code Goes Here #########
        if connect_info:
            self.conn = pymysql.connect(**connect_info)
            self._connect_info = connect_info
        else:
            self.conn = self._default_cnx
            self._connect_info = self._default_connect_info

        self._key_columns = key_columns
        self._table_name = table_name

        print("="*10, " connecting " + self._connect_info.__str__(), "="*10)


        ####### Your Code Goes Here #########


    def get_row_count(self):
        sql = "SELECT COUNT(*) AS count FROM %s" % self._table_name
        res = self._run_q(sql, fetch=True)
        return res[0]['count']


    def __str__(self):
        """

        :return: String representation of the table's metadata.
        """
        ####### Your Code Goes Here #########
        result = "RDBTable %s \n\tRow Count: %s" % (self._table_name, str(self.get_row_count()))
        return result

        ####### Your Code Goes Here #########

    def _run_q(self, q, args=None, fields=None, fetch=True, cnx=None, cursor=None, commit=True):
        """

        :param q: An SQL query string that may have %s slots for argument insertion. The string
            may also have {} after select for columns to choose.
        :param args: A tuple of values to insert in the %s slots.
        :param fetch: If true, return the result.
        :param cnx: A database connection. May be None
        :param cncursor: Do not worry about this for now.
        :param commit: Do not worry about this for now. This is more wizard stuff.
        :return: A result set or None.
        """

        r = None

        cursor_created = False

        if cnx is None:
            cnx = self._get_cnx()

        try:
            # Use the connection in the object if no connection provided.

            # Convert the list of columns into the form "col1, col2, ..." for following SELECT.
            if fields:
                q = q.format(",".join(fields))
            else:
                q = q.format('*')

            if cursor is None:
                cursor = cnx.cursor()  # Just ignore this for now.
                cursor_created = True

            # If debugging is turned on, will print the query sent to the database.
            #self.debug_message("Query = ", cursor.mogrify(q, args))

            cursor.execute(q, args)  # Execute the query.

            # Technically, INSERT, UPDATE and DELETE do not return results.
            # Sometimes the connector libraries return the number of created/deleted rows.
            if fetch:
                r = cursor.fetchall()  # Return all elements of the result.
            else:
                r = None

            if commit:                  # Do not worry about this for now.
                cnx.commit()

            if cursor_created:
                cursor.close()

        except Exception as e:
            print("Exception e = ", e)
            if commit:
                cnx.rollback()
            if cursor_created:
                cursor.close()

        return r

    def _run_insert(self, table_name, column_list, values_list, cnx=None, commit=True):
        """

        :param table_name: Name of the table to insert data. Probably should just get from the object data.
        :param column_list: List of columns for insert.
        :param values_list: List of column values.
        :param cnx: Ignore this for now.
        :param commit: Ignore this for now.
        :return:
        """
        try:
            q = "insert into " + table_name + " "

            # If the column list is not None, form the (col1, col2, ...) part of the statement.
            if column_list is not None:
                q += "(" + ",".join(column_list) + ") "

            # We will use query parameters. For a term of the form values(%s, %s, ...) with one slot for
            # each value to insert.
            values = ["%s"] * len(values_list)

            # Form the values(%s, %s, ...) part of the statement.
            values = " ( " + ",".join(values) + ") "
            values = "values" + values

            # Put all together.
            q += values

            self._run_q(q, args=values_list, fields=None, fetch=False, cnx=cnx, commit=commit)

        except Exception as e:
            print("Got exception = ", e)
            raise e

    def get_folders(self):
        pass

    def get_key_columns(self):
        sql = "SHOW INDEX FROM %s WHERE Key_name = 'PRIMARY';" % self._table_name
        pkList = self._run_q(sql)
        pkList = sorted([(p['Seq_in_index'], p['Column_name']) for p in pkList], key=lambda x: x[0])
        pkList = [i[1] for i in pkList]
        return pkList

    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record.
        :param field_list: A subset of the fields of the record to return.
        :return: None, or a dictionary containing the request fields for the record identified
            by the key.
        """
        ####### Your Code Goes Here #########
        pkList = self.get_key_columns()
        if len(key_fields) != len(pkList):
            raise DataTableException(0,
                 "the length of key_fields is different from the number of primary keys\n\tpk: %s" % ", ".join(pkList)
             )
        sql = "SELECT " + ", ".join(field_list) + " FROM " + self._table_name
        sql += " WHERE " + " AND ".join([c + "=" + str(v)for c, v in zip(pkList, key_fields)])
        return self._run_q(sql)

        ####### Your Code Goes Here #########

    def _template_to_where_clause(self, t):
        """
        Convert a query template into a WHERE clause.
        :param t: Query template.
        :return: (WHERE clause, arg values for %s in clause)
        """
        w_clause = None
        args = None

        ####### Your Code Goes Here #########
        pass

        ####### Your Code Goes Here #########

        return w_clause, args

    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, commit=True,
                         context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}
        :param field_list: A list of request fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A list containing dictionaries. A dictionary is in the list representing each record
            that matches the template. The dictionary only contains the requested fields.
        """
        ####### Your Code Goes Here #########
        extractDict = " AND ".join([k + '=' + str(v) for k, v in template.items()])
        sql = "SELECT " + ", ".join(field_list) + " FROM " + self._table_name
        sql += " WHERE " + extractDict
        return self._run_q(sql)
        ####### Your Code Goes Here #########

    def insert(self, new_record, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records.
        :return: None
        """
        pass

    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    def delete_by_key(self, key_fields, context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def load(self, rows=None):
        pass

    def save(self, context=None):
        pass

    def query(self, query_statement, args, context=None):
        pass

# %% [markdown]
# __Tests__
#
# Test your code below.

# %%
import json
import pymysql


connect_info = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'rv8855741',
    'db': 'W4111GoTSolutionClean',
    'charset': 'utf8mb4',
    'cursorclass': pymysql.cursors.DictCursor
}

def t1():

    print("\n************** t1 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.episdes", connect_info=connect_info)
    print("Table = ", tbl)
    print("\n")
    tbl = RDBDataTable("W4111GoTSolutionClean.episodes")
    print("Table = ", tbl)

    print("\n************** t1 **************\n")


def t2():

    print("\n************** t2 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.episodes")

    res = tbl.find_by_template(
        {"seasonNum": 1},
        field_list=['seasonNum', 'episodeNum', 'episodeTitle']
    )

    print("Answer = ")
    print(json.dumps(res, indent=2, default=str))

    print("\n************** t2 **************\n")


def t3():


    print("\n************** t3 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.scenes")

    res = tbl.find_by_primary_key([3,1, 11],
        field_list=['seasonNum', 'episodeNum', 'sceneNo', "location", "subLocation"]
    )

    print("Answer = \n")
    print(json.dumps(res, indent=2, default=str))


    print("\n************** t3 **************\n")

# %%
t1()
# Out:
# ************** t1 **************
#
# ==========  connecting {'host': '127.0.0.1', 'user': 'root', 'password': 'rv8855741', 'db': 'W4111GoTSolutionClean', 'charset': 'utf8mb4', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Table =  RDBTable W4111GoTSolutionClean.episdes
# 	Row Count: 73
#
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Table =  RDBTable W4111GoTSolutionClean.episodes
# 	Row Count: 73
#
# ************** t1 **************

# %%
t2()
# Out:
# ************** t2 **************
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Answer =
# [
#   {
#     "seasonNum": 1,
#     "episodeNum": 1,
#     "episodeTitle": "Winter Is Coming"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 2,
#     "episodeTitle": "The Kingsroad"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 3,
#     "episodeTitle": "Lord Snow"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 4,
#     "episodeTitle": "Cripples, Bastards, and Broken Things"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 5,
#     "episodeTitle": "The Wolf and the Lion"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 6,
#     "episodeTitle": "A Golden Crown"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 7,
#     "episodeTitle": "You Win or You Die"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 8,
#     "episodeTitle": "The Pointy End"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 9,
#     "episodeTitle": "Baelor"
#   },
#   {
#     "seasonNum": 1,
#     "episodeNum": 10,
#     "episodeTitle": "Fire and Blood"
#   }
# ]
#
# ************** t2 **************

# %%
t3()
# Out:
# ************** t3 **************
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Answer =
#
# [
#   {
#     "seasonNum": 3,
#     "episodeNum": 1,
#     "sceneNo": 11,
#     "location": "North of the Wall",
#     "subLocation": "Frostfang Mountains"
#   }
# ]
#
# ************** t3 **************
